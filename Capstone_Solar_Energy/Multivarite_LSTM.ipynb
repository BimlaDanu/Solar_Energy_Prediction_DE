# %% [markdown]
# ## Setup for EDA and time series

# %%
#pip install xgboost

# %%
# Importing required libraries
import requests
import pandas as pd
import csv
import numpy as np
from itertools import permutations

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# this for time series
#import statsmodels.formula.api as smf
#from statsmodels.tsa.seasonal import seasonal_decompose
#from scipy.ndimage import gaussian_filter
#from calendar import monthrange
#from calendar import month_name
#from sklearn.metrics import mean_squared_error
#from math import sqrt
#from statsmodels.tsa.stattools import adfuller,kpss
#from statsmodels.tsa.seasonal import seasonal_decompose
#from statsmodels.tsa.arima_model import ARIMA
#from statsmodels.graphics.tsaplots import plot_pacf
#from pmdarima.arima import auto_arima
#import statsmodels.graphics.tsaplots as tsaplot
#from statsmodels.tsa.holtwinters import Holt, ExponentialSmoothing, SimpleExpSmoothing

#import tensorflow as tf
#from keras.models import Sequential
#from keras.layers import LSTM, Dense

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.models import load_model
#from keras.callbacks import EarlyStopping
import time
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
#from keras.callbacks import EarlyStopping
import time
import matplotlib.dates as mdates

# %%
#from statsmodels.tsa.stattools import adfuller
#!pip install pmdarima --quiet
#import pmdarima as pm

# %% [markdown]
# ### Columns
# |Name                | Description                                                                   | Type     |Energy Source
# |---------------------|-------------------------------------------------------------------------------|----------|----------|
# | Area       |     Whole Germany                          |object   |     |
# | Mtu     |                                  | object  |    |
# | Biomass_mwh         |     Biomass                 | float64 |Renewable |
# | Fossil_brown_coal_mwh      | Fossil brown coal              | float64 |Fossil  Fuels|
# | Fossil_coal_derived_gas_mwh    |    Fossil coal derived gas       | float64 |Fossil  Fuels |
# | Fossil_gas_mwh      |      Fossil gas                | float64 |Fossil  Fuels|
# | Fossil_hard_coal_mwh     |      Fossil hard coal           | float64 |Fossil  Fuels|
# | Fossil_oil_mwh      |       Fossil oil               | float64 |Fossil  Fuels|
# | Fossil_oil_shale_mwh     |    Fossil oil shale             | float64 |Fossil  Fuels   |
# | Fossil_peat_mwh     |   Fossil peat                    | float64 |Fossil  Fuels |
# | Geothermal_mwh    |        Geothermal                | float64 |Renewable|
# | Hydro_pumped_storage_aggregated_mwh  | Hydro pumped storage (generation)    | float64 |    |
# | Hydro_pumped_storage_consumption_mwh   | Hydro pumped storage (consumption)| float64 |    |
# | Hydro_run_of_river_and_poundage_mwh   | Hydro run of river and poundage   | float64 |Renewable|
# | Hydro_water_reservoir_mwh  |    Hydro water reservoir             | float64 |Renewable|
# | Marine_mwh     |   Marine                        | float64 |Renewable|
# | Nuclear_mwh  |       Nuclear                       | float64 |Nuclear   |
# | Other_mwh     |       Other                     | float64 |    |
# | Other_renewable_mwh     |    Other renewable              | float64 |Renewable|
# | Solar_mwh     |      Solar                      | float64 |Renewable |
# | Waste_mwh    |     Waste                        | float64 |Renewable  |
# | Wind_offshore_mwh    |  Wind offshore                   | float6  |Renewable |
# | Wind_onshore_mwh   |      Wind onshore                 | float64 |Renewable  |
# | Date                  |   Date(yyyy-mm-dd)                 | int64 |    |
# | Hour        |Timesatmp of 'UTC+1' timezone                          | int64 |    |
# | Total_energy_generation_mwh   | Total energy generation of Germany           | float64 |    |
# | Total_other_renewable_mwh   | Total renewable energy generation (excluding solar)  of Germany           | float64 |    |

# %% [markdown]
# #### Dataframes details
# - res_df $\rightarrow$  Import  the original  data
# - data_df_mwh  $\rightarrow$   Data in mwh units (This copy of original data)
# - data_df_gwh  $\rightarrow$  Data in gwh units
# - data_df  $\rightarrow$  Contain the final preprocessing data in mwh/gwh units
# - df_dt is final dataframe for XG Boost regressor (only contain the 'datatime' and  'target' features)

# %% [markdown]
# ### Units of Solar Energy production
# - One kilowatt (kW) =  1,000 watts,
# - One megawatt (MW) =  1,000 kilowatts,
# - One gigawatt (GW) =  1,000 megawatts,
# - One terawatt (TW) =  1,000 gigawatts.

# %%
# Target columns   total_energy_generation_mwh, solar_mwh

# %%
# Import data
#This is data file of 20.07.2023
#res_df = pd.read_csv('data/result_20150101-20230716_cond2.csv')
# This is updated data file of 24.07.2023
df_m = pd.read_csv('data/Result_20150101-20230716_monthly.csv')
df_m.head()
# Out:
#                 dt_date_hour  biomass_mwh  fossil_brown_coal_mwh  \
# 0  2015-01-31 00:00:00+01:00   2963450.25            11800178.50
# 1  2015-02-28 00:00:00+01:00   2692398.25            11249758.00
# 2  2015-03-31 00:00:00+01:00   2935810.25            12187410.00
# 3  2015-04-30 00:00:00+01:00   2845630.00            10203658.25
# 4  2015-05-31 00:00:00+01:00   2918058.50             8934112.50
#
#    fossil_coal_derived_gas_mwh  fossil_gas_mwh  fossil_hard_coal_mwh  \
# 0                          0.0      1405692.50            6387684.50
# 1                          0.0      1615355.25            7886900.00
# 2                      25511.0      1361677.50            7322739.75
# 3                          0.0       849546.00            5998567.50
# 4                          0.0       866311.50            4289877.75
#
#    fossil_oil_mwh  fossil_oil_shale_mwh  fossil_peat_mwh  geothermal_mwh  ...  \
# 0       130717.25                   0.0              0.0         9665.00  ...
# 1       145943.00                   0.0              0.0         9820.75  ...
# 2       152918.25                   0.0              0.0         7920.75  ...
# 3       145577.25                   0.0              0.0         9943.00  ...
# 4       143307.25                   0.0              0.0        12335.00  ...
#
#    day_ahead_auction_volume_weighted_eur_per_mwh  \
# 0                                          30.46
# 1                                          36.66
# 2                                          30.67
# 3                                          29.04
# 4                                          25.32
#
#    intraday_continuous_volume_weighted_eur_per_mwh  \
# 0                                            31.54
# 1                                            37.91
# 2                                            33.00
# 3                                            28.64
# 4                                            26.34
#
#    intraday_continuous_30min_volume_weighted_eur_per_mwh  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    intraday_continuous_15min_volume_weighted_eur_per_mwh  \
# 0                                              31.50
# 1                                              37.12
# 2                                              32.97
# 3                                              29.27
# 4                                              25.38
#
#    intraday_auction_15_minutes_call_eur_per_mwh  \
# 0                                         28.85
# 1                                         36.84
# 2                                         31.26
# 3                                         29.51
# 4                                         24.85
#
#    co2_emission_allowances_auction_eur_per_tco2  gas_ncg_eur_per_tco2  \
# 0                                          6.80                   NaN
# 1                                          7.13                   NaN
# 2                                          6.67                   NaN
# 3                                          6.98                   NaN
# 4                                          7.34                   NaN
#
#    mean_air_temperature_de_c  mean_sunshine_duration_de_minute  \
# 0                       2.19                              35.3
# 1                       0.72                              88.0
# 2                       5.18                             139.1
# 3                       8.42                             224.5
# 4                      12.34                             187.0
#
#    mean_precipitation_de_mm
# 0                      85.4
# 1                      22.3
# 2                      55.5
# 3                      41.4
# 4                      51.7
#
# [5 rows x 45 columns]

# %%
df_m.shape
# Out:
# (102, 45)

# %%
print('df_ms_hape=',df_m.shape)
# Out:
# df_ms_hape= (102, 45)

# %%
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 45 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   dt_date_hour                                           102 non-null    object
#  1   biomass_mwh                                            102 non-null    float64
#  2   fossil_brown_coal_mwh                                  102 non-null    float64
#  3   fossil_coal_derived_gas_mwh                            102 non-null    float64
#  4   fossil_gas_mwh                                         102 non-null    float64
#  5   fossil_hard_coal_mwh                                   102 non-null    float64
#  6   fossil_oil_mwh                                         102 non-null    float64
#  7   fossil_oil_shale_mwh                                   102 non-null    float64
#  8   fossil_peat_mwh                                        102 non-null    float64
#  9   geothermal_mwh                                         102 non-null    float64
#  10  hydro_pumped_storage_aggregated_mwh                    102 non-null    float64
#  11  hydro_pumped_storage_consumption_mwh                   102 non-null    float64
#  12  hydro_run_of_river_and_poundage_mwh                    102 non-null    float64
#  13  hydro_water_reservoir_mwh                              102 non-null    float64
#  14  marine_mwh                                             102 non-null    float64
#  15  nuclear_mwh                                            102 non-null    float64
#  16  other_mwh                                              102 non-null    float64
#  17  other_renewable_mwh                                    102 non-null    float64
#  18  solar_mwh                                              102 non-null    float64
#  19  waste_mwh                                              102 non-null    float64
#  20  wind_offshore_mwh                                      102 non-null    float64
#  21  wind_onshore_mwh                                       102 non-null    float64
#  22  total_energy_generation_mwh                            102 non-null    float64
#  23  solar_gwh                                              102 non-null    float64
#  24  total_energy_generation_gwh                            102 non-null    float64
#  25  dt_year                                                102 non-null    int64
#  26  dt_month                                               102 non-null    int64
#  27  dt_monthname                                           102 non-null    object
#  28  dt_date                                                102 non-null    object
#  29  solar_twh                                              102 non-null    float64
#  30  biomass_gw                                             102 non-null    float64
#  31  wind_offshore_gw                                       91 non-null     float64
#  32  wind_onshore_gw                                        102 non-null    float64
#  33  solar_gw                                               102 non-null    float64
#  34  spot_market_price_eur_per_mwh                          102 non-null    float64
#  35  day_ahead_auction_volume_weighted_eur_per_mwh          102 non-null    float64
#  36  intraday_continuous_volume_weighted_eur_per_mwh        102 non-null    float64
#  37  intraday_continuous_30min_volume_weighted_eur_per_mwh  76 non-null     float64
#  38  intraday_continuous_15min_volume_weighted_eur_per_mwh  102 non-null    float64
#  39  intraday_auction_15_minutes_call_eur_per_mwh           102 non-null    float64
#  40  co2_emission_allowances_auction_eur_per_tco2           102 non-null    float64
#  41  gas_ncg_eur_per_tco2                                   93 non-null     float64
#  42  mean_air_temperature_de_c                              102 non-null    float64
#  43  mean_sunshine_duration_de_minute                       102 non-null    float64
#  44  mean_precipitation_de_mm                               102 non-null    float64
# dtypes: float64(40), int64(2), object(3)
# memory usage: 36.0+ KB

# %%
# Cerate a working data frame
#importing data in original units 
data_dfm_mwh = df_m.copy()
#data_df_mwh.head()

# %% [markdown]
# #### Here we add new columns to data frame

# %%
data_dfm_mwh.columns
# Out:
# Index(['dt_date_hour', 'biomass_mwh', 'fossil_brown_coal_mwh',
#        'fossil_coal_derived_gas_mwh', 'fossil_gas_mwh', 'fossil_hard_coal_mwh',
#        'fossil_oil_mwh', 'fossil_oil_shale_mwh', 'fossil_peat_mwh',
#        'geothermal_mwh', 'hydro_pumped_storage_aggregated_mwh',
#        'hydro_pumped_storage_consumption_mwh',
#        'hydro_run_of_river_and_poundage_mwh', 'hydro_water_reservoir_mwh',
#        'marine_mwh', 'nuclear_mwh', 'other_mwh', 'other_renewable_mwh',
#        'solar_mwh', 'waste_mwh', 'wind_offshore_mwh', 'wind_onshore_mwh',
#        'total_energy_generation_mwh', 'solar_gwh',
#        'total_energy_generation_gwh', 'dt_year', 'dt_month', 'dt_monthname',
#        'dt_date', 'solar_twh', 'biomass_gw', 'wind_offshore_gw',
#        'wind_onshore_gw', 'solar_gw', 'spot_market_price_eur_per_mwh',
#        'day_ahead_auction_volume_weighted_eur_per_mwh',
#        'intraday_continuous_volume_weighted_eur_per_mwh',
#        'intraday_continuous_30min_volume_weighted_eur_per_mwh',
#        'intraday_continuous_15min_volume_weighted_eur_per_mwh',
#        'intraday_auction_15_minutes_call_eur_per_mwh',
#        'co2_emission_allowances_auction_eur_per_tco2', 'gas_ncg_eur_per_tco2',
#        'mean_air_temperature_de_c', 'mean_sunshine_duration_de_minute',
#        'mean_precipitation_de_mm'],
#       dtype='object')

# %%
#data_dfm_mwh['diff_total_energy_and_solar_mwh'] =  data_dfm_mwh['total_energy_generation_mwh'] - data_dfm_mwh['solar_mwh']
# Total renewable energy column other than solar 
#data_dfm_mwh['total_other_renewable_mwh'] = data_dfm_mwh['wind_onshore_mwh'] + data_dfm_mwh['wind_offshore_mwh'] + data_dfm_mwh['waste_mwh']
#+ data_dfm_mwh['other_renewable_mwh'] + data_dfm_mwh['marine_mwh'] + data_dfm_mwh['hydro_run_of_river_and_poundage_mwh'] + data_dfm_mwh['hydro_water_reservoir_mwh'] + data_dfm_mwh['geothermal_mwh']
#data_dfm_mwh.head()

# %% [markdown]
# #### We capitalize the columns names

# %%
##  Capitalize the columns names
data_dfm_mwh.columns = [col.capitalize() for col in data_dfm_mwh.columns]
# Print the dataframe
data_dfm_mwh.head()
# Out:
#                 Dt_date_hour  Biomass_mwh  Fossil_brown_coal_mwh  \
# 0  2015-01-31 00:00:00+01:00   2963450.25            11800178.50
# 1  2015-02-28 00:00:00+01:00   2692398.25            11249758.00
# 2  2015-03-31 00:00:00+01:00   2935810.25            12187410.00
# 3  2015-04-30 00:00:00+01:00   2845630.00            10203658.25
# 4  2015-05-31 00:00:00+01:00   2918058.50             8934112.50
#
#    Fossil_coal_derived_gas_mwh  Fossil_gas_mwh  Fossil_hard_coal_mwh  \
# 0                          0.0      1405692.50            6387684.50
# 1                          0.0      1615355.25            7886900.00
# 2                      25511.0      1361677.50            7322739.75
# 3                          0.0       849546.00            5998567.50
# 4                          0.0       866311.50            4289877.75
#
#    Fossil_oil_mwh  Fossil_oil_shale_mwh  Fossil_peat_mwh  Geothermal_mwh  ...  \
# 0       130717.25                   0.0              0.0         9665.00  ...
# 1       145943.00                   0.0              0.0         9820.75  ...
# 2       152918.25                   0.0              0.0         7920.75  ...
# 3       145577.25                   0.0              0.0         9943.00  ...
# 4       143307.25                   0.0              0.0        12335.00  ...
#
#    Day_ahead_auction_volume_weighted_eur_per_mwh  \
# 0                                          30.46
# 1                                          36.66
# 2                                          30.67
# 3                                          29.04
# 4                                          25.32
#
#    Intraday_continuous_volume_weighted_eur_per_mwh  \
# 0                                            31.54
# 1                                            37.91
# 2                                            33.00
# 3                                            28.64
# 4                                            26.34
#
#    Intraday_continuous_30min_volume_weighted_eur_per_mwh  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Intraday_continuous_15min_volume_weighted_eur_per_mwh  \
# 0                                              31.50
# 1                                              37.12
# 2                                              32.97
# 3                                              29.27
# 4                                              25.38
#
#    Intraday_auction_15_minutes_call_eur_per_mwh  \
# 0                                         28.85
# 1                                         36.84
# 2                                         31.26
# 3                                         29.51
# 4                                         24.85
#
#    Co2_emission_allowances_auction_eur_per_tco2  Gas_ncg_eur_per_tco2  \
# 0                                          6.80                   NaN
# 1                                          7.13                   NaN
# 2                                          6.67                   NaN
# 3                                          6.98                   NaN
# 4                                          7.34                   NaN
#
#    Mean_air_temperature_de_c  Mean_sunshine_duration_de_minute  \
# 0                       2.19                              35.3
# 1                       0.72                              88.0
# 2                       5.18                             139.1
# 3                       8.42                             224.5
# 4                      12.34                             187.0
#
#    Mean_precipitation_de_mm
# 0                      85.4
# 1                      22.3
# 2                      55.5
# 3                      41.4
# 4                      51.7
#
# [5 rows x 45 columns]

# %% [markdown]
# #### Unit conversion from 'mwh' to 'gwh'

# %%
data_dfm_gwh = data_dfm_mwh.copy()
data_dfm_gwh.columns
# Out:
# Index(['Dt_date_hour', 'Biomass_mwh', 'Fossil_brown_coal_mwh',
#        'Fossil_coal_derived_gas_mwh', 'Fossil_gas_mwh', 'Fossil_hard_coal_mwh',
#        'Fossil_oil_mwh', 'Fossil_oil_shale_mwh', 'Fossil_peat_mwh',
#        'Geothermal_mwh', 'Hydro_pumped_storage_aggregated_mwh',
#        'Hydro_pumped_storage_consumption_mwh',
#        'Hydro_run_of_river_and_poundage_mwh', 'Hydro_water_reservoir_mwh',
#        'Marine_mwh', 'Nuclear_mwh', 'Other_mwh', 'Other_renewable_mwh',
#        'Solar_mwh', 'Waste_mwh', 'Wind_offshore_mwh', 'Wind_onshore_mwh',
#        'Total_energy_generation_mwh', 'Solar_gwh',
#        'Total_energy_generation_gwh', 'Dt_year', 'Dt_month', 'Dt_monthname',
#        'Dt_date', 'Solar_twh', 'Biomass_gw', 'Wind_offshore_gw',
#        'Wind_onshore_gw', 'Solar_gw', 'Spot_market_price_eur_per_mwh',
#        'Day_ahead_auction_volume_weighted_eur_per_mwh',
#        'Intraday_continuous_volume_weighted_eur_per_mwh',
#        'Intraday_continuous_30min_volume_weighted_eur_per_mwh',
#        'Intraday_continuous_15min_volume_weighted_eur_per_mwh',
#        'Intraday_auction_15_minutes_call_eur_per_mwh',
#        'Co2_emission_allowances_auction_eur_per_tco2', 'Gas_ncg_eur_per_tco2',
#        'Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute',
#        'Mean_precipitation_de_mm'],
#       dtype='object')

# %%
# Here we convert  unit from mwh to gwh 
#for col in ['Biomass_mwh', 'Fossil_brown_coal_mwh',
#       'Fossil_coal_derived_gas_mwh', 'Fossil_gas_mwh', 'Fossil_hard_coal_mwh',
#       'Fossil_oil_mwh', 'Fossil_oil_shale_mwh', 'Fossil_peat_mwh',
#       'Geothermal_mwh', 'Hydro_pumped_storage_aggregated_mwh',
#       'Hydro_pumped_storage_consumption_mwh',
#       'Hydro_run_of_river_and_poundage_mwh', 'Hydro_water_reservoir_mwh',
#       'Marine_mwh', 'Nuclear_mwh', 'Other_mwh', 'Other_renewable_mwh',
#       'Solar_mwh', 'Waste_mwh', 'Wind_offshore_mwh', 'Wind_onshore_mwh',
#       'Total_energy_generation_mwh', 'Spot_market_price_eur_per_mwh',
#       'Day_ahead_auction_volume_weighted_eur_per_mwh',
#       'Intraday_continuous_volume_weighted_eur_per_mwh',
#       'Intraday_continuous_30min_volume_weighted_eur_per_mwh',
#       'Intraday_continuous_15min_volume_weighted_eur_per_mwh',
#       'Intraday_auction_15_minutes_call_eur_per_mwh']:
#       data_dfm_gwh[col] =  data_dfm_gwh[col]/1000.

# %%
 data_dfm_gwh.columns#,
# Out:
# Index(['Dt_date_hour', 'Biomass_mwh', 'Fossil_brown_coal_mwh',
#        'Fossil_coal_derived_gas_mwh', 'Fossil_gas_mwh', 'Fossil_hard_coal_mwh',
#        'Fossil_oil_mwh', 'Fossil_oil_shale_mwh', 'Fossil_peat_mwh',
#        'Geothermal_mwh', 'Hydro_pumped_storage_aggregated_mwh',
#        'Hydro_pumped_storage_consumption_mwh',
#        'Hydro_run_of_river_and_poundage_mwh', 'Hydro_water_reservoir_mwh',
#        'Marine_mwh', 'Nuclear_mwh', 'Other_mwh', 'Other_renewable_mwh',
#        'Solar_mwh', 'Waste_mwh', 'Wind_offshore_mwh', 'Wind_onshore_mwh',
#        'Total_energy_generation_mwh', 'Solar_gwh',
#        'Total_energy_generation_gwh', 'Dt_year', 'Dt_month', 'Dt_monthname',
#        'Dt_date', 'Solar_twh', 'Biomass_gw', 'Wind_offshore_gw',
#        'Wind_onshore_gw', 'Solar_gw', 'Spot_market_price_eur_per_mwh',
#        'Day_ahead_auction_volume_weighted_eur_per_mwh',
#        'Intraday_continuous_volume_weighted_eur_per_mwh',
#        'Intraday_continuous_30min_volume_weighted_eur_per_mwh',
#        'Intraday_continuous_15min_volume_weighted_eur_per_mwh',
#        'Intraday_auction_15_minutes_call_eur_per_mwh',
#        'Co2_emission_allowances_auction_eur_per_tco2', 'Gas_ncg_eur_per_tco2',
#        'Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute',
#        'Mean_precipitation_de_mm'],
#       dtype='object')

# %%
 data_dfm_gwh.head()
# Out:
#                 Dt_date_hour  Biomass_mwh  Fossil_brown_coal_mwh  \
# 0  2015-01-31 00:00:00+01:00   2963450.25            11800178.50
# 1  2015-02-28 00:00:00+01:00   2692398.25            11249758.00
# 2  2015-03-31 00:00:00+01:00   2935810.25            12187410.00
# 3  2015-04-30 00:00:00+01:00   2845630.00            10203658.25
# 4  2015-05-31 00:00:00+01:00   2918058.50             8934112.50
#
#    Fossil_coal_derived_gas_mwh  Fossil_gas_mwh  Fossil_hard_coal_mwh  \
# 0                          0.0      1405692.50            6387684.50
# 1                          0.0      1615355.25            7886900.00
# 2                      25511.0      1361677.50            7322739.75
# 3                          0.0       849546.00            5998567.50
# 4                          0.0       866311.50            4289877.75
#
#    Fossil_oil_mwh  Fossil_oil_shale_mwh  Fossil_peat_mwh  Geothermal_mwh  ...  \
# 0       130717.25                   0.0              0.0         9665.00  ...
# 1       145943.00                   0.0              0.0         9820.75  ...
# 2       152918.25                   0.0              0.0         7920.75  ...
# 3       145577.25                   0.0              0.0         9943.00  ...
# 4       143307.25                   0.0              0.0        12335.00  ...
#
#    Day_ahead_auction_volume_weighted_eur_per_mwh  \
# 0                                          30.46
# 1                                          36.66
# 2                                          30.67
# 3                                          29.04
# 4                                          25.32
#
#    Intraday_continuous_volume_weighted_eur_per_mwh  \
# 0                                            31.54
# 1                                            37.91
# 2                                            33.00
# 3                                            28.64
# 4                                            26.34
#
#    Intraday_continuous_30min_volume_weighted_eur_per_mwh  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Intraday_continuous_15min_volume_weighted_eur_per_mwh  \
# 0                                              31.50
# 1                                              37.12
# 2                                              32.97
# 3                                              29.27
# 4                                              25.38
#
#    Intraday_auction_15_minutes_call_eur_per_mwh  \
# 0                                         28.85
# 1                                         36.84
# 2                                         31.26
# 3                                         29.51
# 4                                         24.85
#
#    Co2_emission_allowances_auction_eur_per_tco2  Gas_ncg_eur_per_tco2  \
# 0                                          6.80                   NaN
# 1                                          7.13                   NaN
# 2                                          6.67                   NaN
# 3                                          6.98                   NaN
# 4                                          7.34                   NaN
#
#    Mean_air_temperature_de_c  Mean_sunshine_duration_de_minute  \
# 0                       2.19                              35.3
# 1                       0.72                              88.0
# 2                       5.18                             139.1
# 3                       8.42                             224.5
# 4                      12.34                             187.0
#
#    Mean_precipitation_de_mm
# 0                      85.4
# 1                      22.3
# 2                      55.5
# 3                      41.4
# 4                      51.7
#
# [5 rows x 45 columns]

# %%
# data_dfm_gwh.shape

# %%
#data_dfm_gwh.dropna(axis=1)

# %%
 #data_dfm_gwh.shape#data_dfm_gwh.columns

# %% [markdown]
# #### Change columns from mwh to gwh

# %%
# Here we rename columns from *_mwh to *_gwh
for col in data_dfm_gwh.columns:
       data_dfm_gwh.rename(columns={col:col.replace('mwh','gwh')},inplace=True)
       data_dfm_gwh.head()

# %%
 data_dfm_gwh.head()
# Out:
#                 Dt_date_hour  Biomass_gwh  Fossil_brown_coal_gwh  \
# 0  2015-01-31 00:00:00+01:00   2963450.25            11800178.50
# 1  2015-02-28 00:00:00+01:00   2692398.25            11249758.00
# 2  2015-03-31 00:00:00+01:00   2935810.25            12187410.00
# 3  2015-04-30 00:00:00+01:00   2845630.00            10203658.25
# 4  2015-05-31 00:00:00+01:00   2918058.50             8934112.50
#
#    Fossil_coal_derived_gas_gwh  Fossil_gas_gwh  Fossil_hard_coal_gwh  \
# 0                          0.0      1405692.50            6387684.50
# 1                          0.0      1615355.25            7886900.00
# 2                      25511.0      1361677.50            7322739.75
# 3                          0.0       849546.00            5998567.50
# 4                          0.0       866311.50            4289877.75
#
#    Fossil_oil_gwh  Fossil_oil_shale_gwh  Fossil_peat_gwh  Geothermal_gwh  ...  \
# 0       130717.25                   0.0              0.0         9665.00  ...
# 1       145943.00                   0.0              0.0         9820.75  ...
# 2       152918.25                   0.0              0.0         7920.75  ...
# 3       145577.25                   0.0              0.0         9943.00  ...
# 4       143307.25                   0.0              0.0        12335.00  ...
#
#    Day_ahead_auction_volume_weighted_eur_per_gwh  \
# 0                                          30.46
# 1                                          36.66
# 2                                          30.67
# 3                                          29.04
# 4                                          25.32
#
#    Intraday_continuous_volume_weighted_eur_per_gwh  \
# 0                                            31.54
# 1                                            37.91
# 2                                            33.00
# 3                                            28.64
# 4                                            26.34
#
#    Intraday_continuous_30min_volume_weighted_eur_per_gwh  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Intraday_continuous_15min_volume_weighted_eur_per_gwh  \
# 0                                              31.50
# 1                                              37.12
# 2                                              32.97
# 3                                              29.27
# 4                                              25.38
#
#    Intraday_auction_15_minutes_call_eur_per_gwh  \
# 0                                         28.85
# 1                                         36.84
# 2                                         31.26
# 3                                         29.51
# 4                                         24.85
#
#    Co2_emission_allowances_auction_eur_per_tco2  Gas_ncg_eur_per_tco2  \
# 0                                          6.80                   NaN
# 1                                          7.13                   NaN
# 2                                          6.67                   NaN
# 3                                          6.98                   NaN
# 4                                          7.34                   NaN
#
#    Mean_air_temperature_de_c  Mean_sunshine_duration_de_minute  \
# 0                       2.19                              35.3
# 1                       0.72                              88.0
# 2                       5.18                             139.1
# 3                       8.42                             224.5
# 4                      12.34                             187.0
#
#    Mean_precipitation_de_mm
# 0                      85.4
# 1                      22.3
# 2                      55.5
# 3                      41.4
# 4                      51.7
#
# [5 rows x 45 columns]

# %%
 data_dfm_gwh.columns
# Out:
# Index(['Dt_date_hour', 'Biomass_gwh', 'Fossil_brown_coal_gwh',
#        'Fossil_coal_derived_gas_gwh', 'Fossil_gas_gwh', 'Fossil_hard_coal_gwh',
#        'Fossil_oil_gwh', 'Fossil_oil_shale_gwh', 'Fossil_peat_gwh',
#        'Geothermal_gwh', 'Hydro_pumped_storage_aggregated_gwh',
#        'Hydro_pumped_storage_consumption_gwh',
#        'Hydro_run_of_river_and_poundage_gwh', 'Hydro_water_reservoir_gwh',
#        'Marine_gwh', 'Nuclear_gwh', 'Other_gwh', 'Other_renewable_gwh',
#        'Solar_gwh', 'Waste_gwh', 'Wind_offshore_gwh', 'Wind_onshore_gwh',
#        'Total_energy_generation_gwh', 'Solar_gwh',
#        'Total_energy_generation_gwh', 'Dt_year', 'Dt_month', 'Dt_monthname',
#        'Dt_date', 'Solar_twh', 'Biomass_gw', 'Wind_offshore_gw',
#        'Wind_onshore_gw', 'Solar_gw', 'Spot_market_price_eur_per_gwh',
#        'Day_ahead_auction_volume_weighted_eur_per_gwh',
#        'Intraday_continuous_volume_weighted_eur_per_gwh',
#        'Intraday_continuous_30min_volume_weighted_eur_per_gwh',
#        'Intraday_continuous_15min_volume_weighted_eur_per_gwh',
#        'Intraday_auction_15_minutes_call_eur_per_gwh',
#        'Co2_emission_allowances_auction_eur_per_tco2', 'Gas_ncg_eur_per_tco2',
#        'Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute',
#        'Mean_precipitation_de_mm'],
#       dtype='object')

# %%
#columns_to_keep= ['Date', 'Solar_gwh', 'Total_energy_generation_gwh','Wind_offshore_gwh', 'Wind_onshore_gwh', 'Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute',
#      'Mean_precipitation_de_mm', 'Spot_market_price_eur_per_gwh''Co2_emission_allowances_auction_eur_per_tco2', 'Gas_ncg_eur_per_tco2']

#columns_to_keep = ['Dt_date', 'Solar_gwh', 'Total_energy_generation_gwh','Wind_offshore_gwh', 'Wind_onshore_gwh', 'Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute',
#       'Mean_precipitation_de_mm', 'Spot_market_price_eur_per_gwh','Co2_emission_allowances_auction_eur_per_tco2']

columns_to_keep = ['Dt_date', 'Solar_gwh', 'Total_energy_generation_gwh','Wind_offshore_gwh', 'Wind_onshore_gwh', 'Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute',
       'Mean_precipitation_de_mm', 'Spot_market_price_eur_per_gwh','Co2_emission_allowances_auction_eur_per_tco2']
DE_df =  data_dfm_gwh[columns_to_keep].copy()
DE_df.rename(columns = {'Dt_date': 'Date'}, inplace = True)  
DE_df.head()
# Out:
#       Date   Solar_gwh   Solar_gwh  Total_energy_generation_gwh  \
# 0  2015-01   559673.50   559.67350                  48457210.75
# 1  2015-02  1371004.25  1371.00425                  45236359.25
# 2  2015-03  2858577.25  2858.57725                  48570395.00
# 3  2015-04  4435389.00  4435.38900                  43019152.25
# 4  2015-05  4411590.00  4411.59000                  40061007.75
#
#    Total_energy_generation_gwh  Wind_offshore_gwh  Wind_onshore_gwh  \
# 0                  48457.21075          264492.75        9299842.50
# 1                  45236.35925          284792.00        5108908.25
# 2                  48570.39500          435452.50        6706334.75
# 3                  43019.15225          379292.75        4776855.50
# 4                  40061.00775          567571.50        4780908.50
#
#    Mean_air_temperature_de_c  Mean_sunshine_duration_de_minute  \
# 0                       2.19                              35.3
# 1                       0.72                              88.0
# 2                       5.18                             139.1
# 3                       8.42                             224.5
# 4                      12.34                             187.0
#
#    Mean_precipitation_de_mm  Spot_market_price_eur_per_gwh  \
# 0                      85.4                          31.05
# 1                      22.3                          36.72
# 2                      55.5                          31.34
# 3                      41.4                          29.72
# 4                      51.7                          25.36
#
#    Co2_emission_allowances_auction_eur_per_tco2
# 0                                          6.80
# 1                                          7.13
# 2                                          6.67
# 3                                          6.98
# 4                                          7.34

# %%
df_gwh = DE_df.loc[:,~DE_df.columns.duplicated()]
#DE_df.T.drop_duplicates().T
df_gwh.head()
# Out:
#       Date   Solar_gwh  Total_energy_generation_gwh  Wind_offshore_gwh  \
# 0  2015-01   559673.50                  48457210.75          264492.75
# 1  2015-02  1371004.25                  45236359.25          284792.00
# 2  2015-03  2858577.25                  48570395.00          435452.50
# 3  2015-04  4435389.00                  43019152.25          379292.75
# 4  2015-05  4411590.00                  40061007.75          567571.50
#
#    Wind_onshore_gwh  Mean_air_temperature_de_c  \
# 0        9299842.50                       2.19
# 1        5108908.25                       0.72
# 2        6706334.75                       5.18
# 3        4776855.50                       8.42
# 4        4780908.50                      12.34
#
#    Mean_sunshine_duration_de_minute  Mean_precipitation_de_mm  \
# 0                              35.3                      85.4
# 1                              88.0                      22.3
# 2                             139.1                      55.5
# 3                             224.5                      41.4
# 4                             187.0                      51.7
#
#    Spot_market_price_eur_per_gwh  Co2_emission_allowances_auction_eur_per_tco2
# 0                          31.05                                          6.80
# 1                          36.72                                          7.13
# 2                          31.34                                          6.67
# 3                          29.72                                          6.98
# 4                          25.36                                          7.34

# %%
df_gwh.columns
# Out:
# Index(['Date', 'Solar_gwh', 'Total_energy_generation_gwh', 'Wind_offshore_gwh',
#        'Wind_onshore_gwh', 'Mean_air_temperature_de_c',
#        'Mean_sunshine_duration_de_minute', 'Mean_precipitation_de_mm',
#        'Spot_market_price_eur_per_gwh',
#        'Co2_emission_allowances_auction_eur_per_tco2'],
#       dtype='object')

# %%
# Here we convert  unit from mwh to gwh 
for col in ['Solar_gwh', 'Total_energy_generation_gwh','Wind_offshore_gwh', 'Wind_onshore_gwh', 'Spot_market_price_eur_per_gwh']:
       df_gwh[col] =  df_gwh[col]/(1000.)
df_gwh.head()
# Out:
# /var/folders/75/2hrhpj_x0q94k87nqmpdwckm0000gn/T/ipykernel_88855/2055906904.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gwh[col] =  df_gwh[col]/(1000.)
#       Date   Solar_gwh  Total_energy_generation_gwh  Wind_offshore_gwh  \
# 0  2015-01   559.67350                  48457.21075          264.49275
# 1  2015-02  1371.00425                  45236.35925          284.79200
# 2  2015-03  2858.57725                  48570.39500          435.45250
# 3  2015-04  4435.38900                  43019.15225          379.29275
# 4  2015-05  4411.59000                  40061.00775          567.57150
#
#    Wind_onshore_gwh  Mean_air_temperature_de_c  \
# 0        9299.84250                       2.19
# 1        5108.90825                       0.72
# 2        6706.33475                       5.18
# 3        4776.85550                       8.42
# 4        4780.90850                      12.34
#
#    Mean_sunshine_duration_de_minute  Mean_precipitation_de_mm  \
# 0                              35.3                      85.4
# 1                              88.0                      22.3
# 2                             139.1                      55.5
# 3                             224.5                      41.4
# 4                             187.0                      51.7
#
#    Spot_market_price_eur_per_gwh  Co2_emission_allowances_auction_eur_per_tco2
# 0                        0.03105                                          6.80
# 1                        0.03672                                          7.13
# 2                        0.03134                                          6.67
# 3                        0.02972                                          6.98
# 4                        0.02536                                          7.34

# %%
data_df = df_gwh.copy()

# %%
 data_df.shape,  data_df.columns
# Out:
# ((102, 10),
#  Index(['Date', 'Solar_gwh', 'Total_energy_generation_gwh', 'Wind_offshore_gwh',
#         'Wind_onshore_gwh', 'Mean_air_temperature_de_c',
#         'Mean_sunshine_duration_de_minute', 'Mean_precipitation_de_mm',
#         'Spot_market_price_eur_per_gwh',
#         'Co2_emission_allowances_auction_eur_per_tco2'],
#        dtype='object'))

# %%
def extract_year_month(df, date_column):
    # Convert the date column to pandas datetime
    df[date_column] = pd.to_datetime(df[date_column])

    # Extract year and month from the date column and create new columns for them
    df['Year'] = df[date_column].dt.year
    df['Month'] = df[date_column].dt.month

    # Drop the original date column if needed
    # df.drop(columns=[date_column], inplace=True)

    return df
data_df = extract_year_month( data_df, 'Date')
data_df.head()
# Out:
#         Date   Solar_gwh  Total_energy_generation_gwh  Wind_offshore_gwh  \
# 0 2015-01-01   559.67350                  48457.21075          264.49275
# 1 2015-02-01  1371.00425                  45236.35925          284.79200
# 2 2015-03-01  2858.57725                  48570.39500          435.45250
# 3 2015-04-01  4435.38900                  43019.15225          379.29275
# 4 2015-05-01  4411.59000                  40061.00775          567.57150
#
#    Wind_onshore_gwh  Mean_air_temperature_de_c  \
# 0        9299.84250                       2.19
# 1        5108.90825                       0.72
# 2        6706.33475                       5.18
# 3        4776.85550                       8.42
# 4        4780.90850                      12.34
#
#    Mean_sunshine_duration_de_minute  Mean_precipitation_de_mm  \
# 0                              35.3                      85.4
# 1                              88.0                      22.3
# 2                             139.1                      55.5
# 3                             224.5                      41.4
# 4                             187.0                      51.7
#
#    Spot_market_price_eur_per_gwh  \
# 0                        0.03105
# 1                        0.03672
# 2                        0.03134
# 3                        0.02972
# 4                        0.02536
#
#    Co2_emission_allowances_auction_eur_per_tco2  Year  Month
# 0                                          6.80  2015      1
# 1                                          7.13  2015      2
# 2                                          6.67  2015      3
# 3                                          6.98  2015      4
# 4                                          7.34  2015      5

# %%
def average_lineplot(df, y_values, x='Date', time='Year'):
    fig, ax = plt.subplots(figsize=(10, 6))

    for y in y_values:
        grouped_df = df \
            .groupby([x, time], as_index=False) \
            .agg({y: np.sum}) \
            .set_index(x)

        y_label_00 = y.replace('_gwh', ' (GWh)')
        y_label_target0 = y_label_00.replace('_', ' ')

        sns.lineplot(x=time, y=y, data=grouped_df, ax=ax, label=y_label_target0, marker='o')

    ax.set(title='', ylabel='Energy generation in (GWh)')
    ax.tick_params(axis='x', rotation=45)
    ax.legend()
    plt.tight_layout()

    # Remove '(GWh)' from the legend labels
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles=handles, labels=[label.replace(' (GWh)', '') for label in labels])
    plt.show()

def simple_lineplot(df, y_values, x='Date', time=' '):
    fig, ax = plt.subplots(figsize=(10, 6))

    for y in y_values:
        grouped_df = df \
            .groupby([x, time], as_index=False) \
            .agg({y: np.sum}) \
            .set_index(x)

        y_label_00 = y.replace('_gwh', ' (GWh)')
        y_label_target0 = y_label_00.replace('_', ' ')

        sns.lineplot(x=time, y=y, data=grouped_df, ax=ax, label=y_label_target0, marker='o')

    ax.set(title='', ylabel='Weather conditions')
    ax.tick_params(axis='x', rotation=45)
    ax.legend()
    plt.tight_layout()

    # Remove '(GWh)' from the legend labels
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles=handles, labels=[label.replace(' (GWh)', '') for label in labels])
    plt.show()

average_lineplot(df=data_df, y_values=['Solar_gwh', 'Wind_onshore_gwh', 'Wind_offshore_gwh'], x="Date", time='Month')   
#average_lineplot(df=data_df, y_values=['Total_energy_generation_gwh', 'Solar_gwh', 'Wind_onshore_gwh', 'Wind_offshore_gwh'], x="Date", time='Month')
#average_lineplot(df=data_df, y_values=['Wind_onshore_gwh', 'Wind_offshore_gwh'], x="Date", time='Month')

simple_lineplot(df=data_df, y_values=['Mean_air_temperature_de_c',
        'Mean_sunshine_duration_de_minute', 'Mean_precipitation_de_mm',
        'Spot_market_price_eur_per_gwh',
        'Co2_emission_allowances_auction_eur_per_tco2'], x="Date", time='Month')

# %%
#'Total_energy_generation_gwh', 'Solar_gwh', 'Wind_onshore_gwh', 'Wind_offshore_gwh'
sns.distplot(data_df['Total_energy_generation_gwh'])
plt.title("Total Energy  Distribution")
plt.show()
sns.distplot(data_df['Solar_gwh'])
plt.title("Solar Energy  Distribution")
plt.show()
sns.distplot(data_df['Wind_onshore_gwh'])
plt.title("Wind Onshore Energy  Distribution")
plt.show()
# Out:
# /var/folders/75/2hrhpj_x0q94k87nqmpdwckm0000gn/T/ipykernel_88855/2155932804.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_df['Total_energy_generation_gwh'])
# /var/folders/75/2hrhpj_x0q94k87nqmpdwckm0000gn/T/ipykernel_88855/2155932804.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_df['Solar_gwh'])
# /var/folders/75/2hrhpj_x0q94k87nqmpdwckm0000gn/T/ipykernel_88855/2155932804.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_df['Wind_onshore_gwh'])

# %%
def plot_line_function(df, y_values, x='Date', time='Month'):
    # Convert the 'Date' column to pandas datetime with 'Year-Month' format
    df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m')

    fig, ax = plt.subplots(figsize=(10, 6))

    for y in y_values:
        sns.lineplot(x=time, y=y, data=df, ax=ax, label=y, marker='o')

    ax.set(title='', ylabel='Weather conditions')
    ax.tick_params(axis='x', rotation=45)
    ax.legend()
    plt.tight_layout()

    plt.show()
columns_to_plot = ['Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute', 'Mean_precipitation_de_mm', 'Spot_market_price_eur_per_gwh', 'Co2_emission_allowances_auction_eur_per_tco2']
#columns_to_plot = ['Solar_gwh', 'Total_energy_generation_gwh', 'Wind_offshore_gwh', 'Wind_onshore_gwh', 'Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute', 'Mean_precipitation_de_mm', 'Spot_market_price_eur_per_gwh', 'Co2_emission_allowances_auction_eur_per_tco2']
plot_line_function(df=data_df, y_values=columns_to_plot, x="date", time='Date')

columns_to_plot1 = ['Mean_air_temperature_de_c', 'Spot_market_price_eur_per_gwh', 'Co2_emission_allowances_auction_eur_per_tco2']
plot_line_function(df=data_df, y_values=columns_to_plot1, x="date", time='Date')

# %%
#['Dt_date', 'Solar_gwh', 'Total_energy_generation_gwh','Wind_offshore_gwh', 'Wind_onshore_gwh', 'Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute',
#       'Mean_precipitation_de_mm', 'Spot_market_price_eur_per_gwh','Co2_emission_allowances_auction_eur_per_tco2']
## Energy development over year (time)
fig, ax = plt.subplots()
sns.lineplot(x='Date', y='Total_energy_generation_gwh', data=data_df, ax=ax)
ax.set(title='Total energy generation (Monthly)', ylabel='Total energy generation(Gwh)');

# %% [markdown]
# #### Univariate LSTM for energy generation

# %% [markdown]
# #### best version

# %%
import matplotlib.dates as mdates   #from keras.layers import LSTM, Dense
def create_sequences(data, lookback):
    X, y = [], []
    for i in range(len(data) - lookback):
        X.append(data[i:i+lookback])
        y.append(data[i+lookback])
    return np.array(X), np.array(y)

def lstm_model(target, data_df, lookback):
   
    target_label = target.replace('_gwh', ' (GWh)').replace('_', ' ')
    main_target = target.replace('_', ' ').replace('gwh', '(monthly)')
    
    dfs = data_df[['Date', target]]
    dfs['Date'] = pd.to_datetime(dfs['Date'])
    dfs.set_index('Date', inplace=True)
    
    scaler = MinMaxScaler(feature_range=(0, 1))
    data_scaled = scaler.fit_transform(dfs[target].values.reshape(-1, 1))
   
    X_lstm, y_lstm = create_sequences(data_scaled, lookback)
    
    train_size = int(len(X_lstm) * 0.8)

    X_train_lstm, X_test_lstm = X_lstm[:train_size], X_lstm[train_size-lookback:]
    y_train_lstm, y_test_lstm = y_lstm[:train_size], y_lstm[train_size-lookback:]


    print('data_df_shape, data_scaled_shape, X_lstm_shape, y_lstm_shape, X_lstm_shape[0]+X_lstm_shape[1]=',data_df.shape, data_scaled.shape, X_lstm.shape, y_lstm.shape, X_lstm.shape[0]+X_lstm.shape[1])
    print('X_train_lstm_shape, X_test_lstm_shape, y_train_lstm_shape, y_test_lstm_shape =',X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape)
    
    print('data_df_shape, data_scaled_shape, X_lstm_shape, y_lstm_shape, X_lstm_shape[0]+X_lstm_shape[1]=',data_df.shape, data_scaled.shape, X_lstm.shape, y_lstm.shape, X_lstm.shape[0]+X_lstm.shape[1])
    print('X_train_lstm_shape, X_test_lstm_shape, y_train_lstm_shape, y_test_lstm_shape =',X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape)
    
    print ('Before model fitting')
    print ('X_test_lstm = ',X_test_lstm.shape)
    print ('y_test_lstm = ',y_test_lstm.shape)
    print ('X_train_lstm = ',X_train_lstm.shape)
    print ('y_train_lstm = ',y_train_lstm.shape)

    model = Sequential()
    model.add(LSTM(units=64, activation='relu', input_shape=(lookback, 1), return_sequences=True))
    model.add(LSTM(units=32, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(X_train_lstm, y_train_lstm, epochs=100, batch_size=30, validation_data=(X_test_lstm, y_test_lstm), verbose=1)
    print(model.summary())
   
    print ('After model fitting')
    print ('X_test_lstm = ',X_test_lstm.shape)
    print ('y_test_lstm = ',y_test_lstm.shape)
    print ('X_train_lstm = ',X_train_lstm.shape)
    print ('y_train_lstm = ',y_train_lstm.shape)
     
    y_pred_train_lstm = model.predict(X_train_lstm)
    y_pred_test_lstm = model.predict(X_test_lstm)
    
    print ('After prediction')
    print ('y_train_lstm = ',y_train_lstm.shape)
    print ('y_pred_train_lstm = ',y_pred_train_lstm.shape)
    print ('X_train_lstm = ',y_train_lstm.shape)

    print ('y_test_lstm = ',y_test_lstm.shape)
    print ('y_pred_test_lstm = ',y_pred_test_lstm.shape)
    print ('X_test_lstm = ',X_test_lstm.shape)
     
    

    y_pred_train_lstm = scaler.inverse_transform(y_pred_train_lstm)
    y_pred_test_lstm = scaler.inverse_transform(y_pred_test_lstm)
    y_train_lstm = scaler.inverse_transform(y_train_lstm)
    y_test_lstm = scaler.inverse_transform(y_test_lstm)

    print ('After inverse transformation on prediction data')
    print ('y_train_lstm = ',y_train_lstm.shape)
    print ('y_pred_train_lstm = ',y_pred_train_lstm.shape)
    print ('X_train_lstm = ',y_train_lstm.shape)

    print ('y_test_lstm = ',y_test_lstm.shape)
    print ('y_pred_test_lstm = ',y_pred_test_lstm.shape)
    print ('X_test_lstm = ',X_test_lstm.shape)
     
    

    train_rmse = np.sqrt(mean_squared_error(y_train_lstm, y_pred_train_lstm))
    test_rmse = np.sqrt(mean_squared_error(y_test_lstm, y_pred_test_lstm))
    train_mse = mean_squared_error(y_train_lstm, y_pred_train_lstm)
    test_mse = mean_squared_error(y_test_lstm, y_pred_test_lstm)
    train_mae = mean_absolute_error(y_train_lstm, y_pred_train_lstm)
    test_mae = mean_absolute_error(y_test_lstm, y_pred_test_lstm)
    train_r2 = r2_score(y_train_lstm, y_pred_train_lstm)
    test_r2 = r2_score(y_test_lstm, y_pred_test_lstm)

    print("Train RMSE:", train_rmse)
    print("Train MSE:", train_mse)
    print("Train MAE:", train_mae)
    print("Train R2 Score:", train_r2)
    print("Test RMSE:", test_rmse)
    print("Test MSE:", test_mse)
    print("Test MAE:", test_mae)
    print("Test R2 Score:", test_r2)

    residuals = y_test_lstm - y_pred_test_lstm

    plt.figure(figsize=(10, 5))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss from history')
    plt.title('Loss vs. Epoch')
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 5))
    plt.scatter(y_test_lstm, residuals, color='blue', alpha=0.6)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.xlabel('True Values')
    plt.ylabel('Residuals')
    plt.title(main_target)
    plt.show()

    plt.figure(figsize=(10, 8))
    plt.scatter(y_test_lstm, y_pred_test_lstm, label='', color='blue')
    plt.plot([y_test_lstm.min(), y_test_lstm.max()], [y_test_lstm.min(), y_test_lstm.max()], 'k--', lw=2, label='')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(main_target)
    plt.show()

    plt.figure(figsize=(15, 5))
    train_index = dfs.index[:train_size][-len(y_train_lstm):]
    test_index = dfs.index[train_size:]
    plt.plot(dfs.index, dfs[target], label='Historical Data', color='gray')
    plt.plot(train_index, y_train_lstm, label='Train Data', color='blue')
    plt.plot(test_index, y_test_lstm, label='Test Data', color='#1f76b4')
    plt.plot(test_index, y_pred_test_lstm, label='Predicted Test Data', color='red')
    plt.plot(train_index, y_pred_train_lstm, label='Predicted Train Data', color='green', linestyle='dashed')
    #plt.axvline(x=train_size, color='gray', linestyle='--', label='Train-Test Split')
    plt.axvline(x=train_index[-1], color='orange', linestyle='--', label='Train-Test Split Point')
    plt.legend()
    plt.xticks([])
    plt.title(main_target)
    plt.ylabel(target_label)
    plt.xlabel('Date')
    plt.show()

    plt.figure(figsize=(15, 5))
    train_index = dfs.index[:train_size][-len(y_train_lstm):]
    test_index = dfs.index[train_size:]
    plt.plot(dfs.index, dfs[target], label='Historical Data', color='gray')
    plt.plot(train_index, y_train_lstm, label='Train Data', color='blue')
    plt.plot(test_index, y_test_lstm, label='Test Data', color='#1f76b4')
    plt.plot(test_index, y_pred_test_lstm, label='Predicted Test Data', color='red')
    plt.plot(train_index, y_pred_train_lstm, label='Predicted Train Data', color='green', linestyle='dashed')
   #plt.axvline(x=train_size, color='gray', linestyle='--', label='Train-Test Split')
    plt.axvline(x=train_index[-1], color='orange', linestyle='--', label='Train-Test Split Point')
    plt.legend()
    # Format date ticks on x-axis
    plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    plt.title(main_target)
    plt.ylabel(target_label)
    plt.xlabel('Date')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
    print(model.summary()) 
    print('X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape, X_lstm.shape, y_lstm.shape, df_shape =', X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape, X_lstm.shape, y_lstm.shape, dfs.shape)

   
    plt.figure(figsize=(15, 5))
    train_index = dfs.index[:train_size][-len(y_train_lstm):]
    test_index = dfs.index[train_size:]
    plt.plot(test_index, y_test_lstm, label='Test Data', color='#1f76b4')
    plt.plot(test_index, y_pred_test_lstm, label='Predicted Test Data', color='red')
    #plt.axvline(x=train_index[-1], color='orange', linestyle='--', label='Train-Test Split Point')
    plt.legend()
    # Format date ticks on x-axis
    plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    plt.title(main_target)
    plt.ylabel(target_label)
    plt.xlabel('Date')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()


    plt.figure(figsize=(15, 5))
    train_index = dfs.index[:train_size][-len(y_train_lstm):]
    test_index = dfs.index[train_size:]
    plt.plot(test_index, y_test_lstm, label='Test Data', color='#1f76b4')
    plt.plot(test_index, y_pred_test_lstm, label='Predicted Test Data', color='red')
    plt.xlim(pd.to_datetime('2023-01-01'), pd.to_datetime('2023-07-31'))  # Set xlim to the specified range
    plt.legend()
    # Format date ticks on x-axis
    plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    plt.title(main_target)
    plt.ylabel(target_label)
    plt.xlabel('Date')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    print(model.summary()) 
    print('X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape, X_lstm.shape, y_lstm.shape, df_shape =', X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape, X_lstm.shape, y_lstm.shape, dfs.shape)

#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

lookback=2
results = lstm_model('Solar_gwh', data_df, lookback)
# Out:
# /var/folders/75/2hrhpj_x0q94k87nqmpdwckm0000gn/T/ipykernel_88855/2372594612.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs['Date'] = pd.to_datetime(dfs['Date'])
# data_df_shape, data_scaled_shape, X_lstm_shape, y_lstm_shape, X_lstm_shape[0]+X_lstm_shape[1]= (102, 12) (102, 1) (100, 2, 1) (100, 1) 102
# X_train_lstm_shape, X_test_lstm_shape, y_train_lstm_shape, y_test_lstm_shape = (80, 2, 1) (22, 2, 1) (80, 1) (22, 1)
# data_df_shape, data_scaled_shape, X_lstm_shape, y_lstm_shape, X_lstm_shape[0]+X_lstm_shape[1]= (102, 12) (102, 1) (100, 2, 1) (100, 1) 102
# X_train_lstm_shape, X_test_lstm_shape, y_train_lstm_shape, y_test_lstm_shape = (80, 2, 1) (22, 2, 1) (80, 1) (22, 1)
# Before model fitting
# X_test_lstm =  (22, 2, 1)
# y_test_lstm =  (22, 1)
# X_train_lstm =  (80, 2, 1)
# y_train_lstm =  (80, 1)
# Epoch 1/100
# 3/3 [==============================] - 1s 82ms/step - loss: 0.1825 - val_loss: 0.3081
# Epoch 2/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1755 - val_loss: 0.2995
# Epoch 3/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1692 - val_loss: 0.2906
# Epoch 4/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1628 - val_loss: 0.2814
# Epoch 5/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1561 - val_loss: 0.2719
# Epoch 6/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1493 - val_loss: 0.2622
# Epoch 7/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1422 - val_loss: 0.2520
# Epoch 8/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1347 - val_loss: 0.2411
# Epoch 9/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1271 - val_loss: 0.2290
# Epoch 10/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1181 - val_loss: 0.2163
# Epoch 11/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1096 - val_loss: 0.2028
# Epoch 12/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1000 - val_loss: 0.1886
# Epoch 13/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0909 - val_loss: 0.1737
# Epoch 14/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0813 - val_loss: 0.1582
# Epoch 15/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0715 - val_loss: 0.1425
# Epoch 16/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0625 - val_loss: 0.1267
# Epoch 17/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0548 - val_loss: 0.1114
# Epoch 18/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0467 - val_loss: 0.0981
# Epoch 19/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0418 - val_loss: 0.0872
# Epoch 20/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0389 - val_loss: 0.0797
# Epoch 21/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0392 - val_loss: 0.0755
# Epoch 22/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0402 - val_loss: 0.0737
# Epoch 23/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0407 - val_loss: 0.0732
# Epoch 24/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0401 - val_loss: 0.0734
# Epoch 25/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0389 - val_loss: 0.0742
# Epoch 26/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0377 - val_loss: 0.0755
# Epoch 27/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0371 - val_loss: 0.0769
# Epoch 28/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0369 - val_loss: 0.0781
# Epoch 29/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0367 - val_loss: 0.0785
# Epoch 30/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0366 - val_loss: 0.0782
# Epoch 31/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0364 - val_loss: 0.0769
# Epoch 32/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0360 - val_loss: 0.0755
# Epoch 33/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0358 - val_loss: 0.0740
# Epoch 34/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0354 - val_loss: 0.0733
# Epoch 35/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0351 - val_loss: 0.0726
# Epoch 36/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0348 - val_loss: 0.0717
# Epoch 37/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0346 - val_loss: 0.0707
# Epoch 38/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0345 - val_loss: 0.0700
# Epoch 39/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0343 - val_loss: 0.0698
# Epoch 40/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0341 - val_loss: 0.0696
# Epoch 41/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0339 - val_loss: 0.0696
# Epoch 42/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0337 - val_loss: 0.0698
# Epoch 43/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0336 - val_loss: 0.0699
# Epoch 44/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0334 - val_loss: 0.0695
# Epoch 45/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0332 - val_loss: 0.0690
# Epoch 46/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0331 - val_loss: 0.0685
# Epoch 47/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0329 - val_loss: 0.0677
# Epoch 48/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0326 - val_loss: 0.0673
# Epoch 49/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0324 - val_loss: 0.0669
# Epoch 50/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0323 - val_loss: 0.0666
# Epoch 51/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0322 - val_loss: 0.0665
# Epoch 52/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0321 - val_loss: 0.0664
# Epoch 53/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0319 - val_loss: 0.0660
# Epoch 54/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0318 - val_loss: 0.0656
# Epoch 55/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0317 - val_loss: 0.0655
# Epoch 56/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0316 - val_loss: 0.0650
# Epoch 57/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0315 - val_loss: 0.0648
# Epoch 58/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0313 - val_loss: 0.0645
# Epoch 59/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0312 - val_loss: 0.0643
# Epoch 60/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0311 - val_loss: 0.0641
# Epoch 61/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0310 - val_loss: 0.0636
# Epoch 62/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0311 - val_loss: 0.0639
# Epoch 63/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0307 - val_loss: 0.0632
# Epoch 64/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0305 - val_loss: 0.0627
# Epoch 65/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0304 - val_loss: 0.0623
# Epoch 66/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0303 - val_loss: 0.0623
# Epoch 67/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0301 - val_loss: 0.0620
# Epoch 68/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0300 - val_loss: 0.0616
# Epoch 69/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0297 - val_loss: 0.0611
# Epoch 70/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0295 - val_loss: 0.0605
# Epoch 71/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0294 - val_loss: 0.0600
# Epoch 72/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0293 - val_loss: 0.0597
# Epoch 73/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0290 - val_loss: 0.0592
# Epoch 74/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0288 - val_loss: 0.0588
# Epoch 75/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0286 - val_loss: 0.0583
# Epoch 76/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0284 - val_loss: 0.0577
# Epoch 77/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0281 - val_loss: 0.0573
# Epoch 78/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0278 - val_loss: 0.0570
# Epoch 79/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0278 - val_loss: 0.0566
# Epoch 80/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0274 - val_loss: 0.0556
# Epoch 81/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0270 - val_loss: 0.0546
# Epoch 82/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0268 - val_loss: 0.0537
# Epoch 83/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0265 - val_loss: 0.0532
# Epoch 84/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0261 - val_loss: 0.0523
# Epoch 85/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0258 - val_loss: 0.0517
# Epoch 86/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0254 - val_loss: 0.0509
# Epoch 87/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0250 - val_loss: 0.0497
# Epoch 88/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0246 - val_loss: 0.0484
# Epoch 89/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0242 - val_loss: 0.0473
# Epoch 90/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0239 - val_loss: 0.0466
# Epoch 91/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0232 - val_loss: 0.0454
# Epoch 92/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0227 - val_loss: 0.0443
# Epoch 93/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0222 - val_loss: 0.0430
# Epoch 94/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0217 - val_loss: 0.0416
# Epoch 95/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0211 - val_loss: 0.0404
# Epoch 96/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0391
# Epoch 97/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0199 - val_loss: 0.0379
# Epoch 98/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0194 - val_loss: 0.0363
# Epoch 99/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0187 - val_loss: 0.0348
# Epoch 100/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0181 - val_loss: 0.0330
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 2, 64)             16896
#
#  lstm_3 (LSTM)               (None, 32)                12416
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 29345 (114.63 KB)
# Trainable params: 29345 (114.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# After model fitting
# X_test_lstm =  (22, 2, 1)
# y_test_lstm =  (22, 1)
# X_train_lstm =  (80, 2, 1)
# y_train_lstm =  (80, 1)
# 3/3 [==============================] - 0s 975us/step
# 1/1 [==============================] - 0s 11ms/step
# After prediction
# y_train_lstm =  (80, 1)
# y_pred_train_lstm =  (80, 1)
# X_train_lstm =  (80, 1)
# y_test_lstm =  (22, 1)
# y_pred_test_lstm =  (22, 1)
# X_test_lstm =  (22, 2, 1)
# After inverse transformation on prediction data
# y_train_lstm =  (80, 1)
# y_pred_train_lstm =  (80, 1)
# X_train_lstm =  (80, 1)
# y_test_lstm =  (22, 1)
# y_pred_test_lstm =  (22, 1)
# X_test_lstm =  (22, 2, 1)
# Train RMSE: 1091.4290604764699
# Train MSE: 1191217.3940525497
# Train MAE: 917.0049813232423
# Train R2 Score: 0.6748875017438565
# Test RMSE: 1497.4462633118737
# Test MSE: 2242345.3115066937
# Test MAE: 1266.6555523792613
# Test R2 Score: 0.6859548839214403
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 2, 64)             16896
#
#  lstm_3 (LSTM)               (None, 32)                12416
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 29345 (114.63 KB)
# Trainable params: 29345 (114.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape, X_lstm.shape, y_lstm.shape, df_shape = (80, 2, 1) (22, 2, 1) (80, 1) (22, 1) (100, 2, 1) (100, 1) (102, 1)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 2, 64)             16896
#
#  lstm_3 (LSTM)               (None, 32)                12416
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 29345 (114.63 KB)
# Trainable params: 29345 (114.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape, X_lstm.shape, y_lstm.shape, df_shape = (80, 2, 1) (22, 2, 1) (80, 1) (22, 1) (100, 2, 1) (100, 1) (102, 1)

# %%
def create_sequences(data, lookback):
    X, y = [], []
    for i in range(len(data) - lookback):
        X.append(data[i:i+lookback])
        y.append(data[i+lookback])
    return np.array(X), np.array(y)

def lstm_model(target, data_df, lookback, sampling_frequency='M'):
    # Prepare the input data
    target_label = target.replace('_gwh', ' (GWh)').replace('_', ' ')
    main_target = target.replace('_', ' ').replace('gwh', '(monthly)')
    
    if sampling_frequency:
        dfs = data_df[['Date', target]]
        dfs['Date'] = pd.to_datetime(dfs['Date'])
        dfs.set_index('Date', inplace=True)
        dfs_resampled = dfs.resample(sampling_frequency).mean()
    else:
        dfs_resampled = data_df
    
    scaler = MinMaxScaler(feature_range=(0, 1))
    data_scaled = scaler.fit_transform(dfs_resampled[target].values.reshape(-1, 1))
    
    X_lstm, y_lstm = create_sequences(data_scaled, lookback)
    
    train_size = int(len(X_lstm) * 0.8)
    X_train_lstm, X_test_lstm = X_lstm[:train_size], X_lstm[train_size-lookback:]
    y_train_lstm, y_test_lstm = y_lstm[:train_size], y_lstm[train_size-lookback:]


    print('data_df_shape, data_scaled_shape, X_lstm_shape, y_lstm_shape, X_lstm_shape[0]+X_lstm_shape[1]=',data_df.shape, data_scaled.shape, X_lstm.shape, y_lstm.shape, X_lstm.shape[0]+X_lstm.shape[1])
    print('X_train_lstm_shape, X_test_lstm_shape, y_train_lstm_shape, y_test_lstm_shape =',X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape)

    
    # Build the LSTM model
    model = Sequential()
    #model.add(LSTM(units=64, activation='relu', input_shape=(lookback, 1), return_sequences=True))
    #model.add(LSTM(units=32, activation='relu'))
    #model.add(Dense(1))
    model.add(LSTM(units=256, activation='relu', input_shape=(lookback, 1), return_sequences=True))
    model.add(LSTM(units=128, activation='relu'))
    model.add(Dense(1, activation='linear'))
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(X_train_lstm, y_train_lstm, epochs=100, batch_size=30, validation_data=(X_test_lstm, y_test_lstm), verbose=1)
    print(model.summary())
  

    # LSTM prediction on test and train data
    y_pred_train_lstm = model.predict(X_train_lstm)
    y_pred_test_lstm = model.predict(X_test_lstm)

    print ('1y_pred_train_lstm = ',y_pred_train_lstm.shape)
    print ('1X_test_lstm = ',X_test_lstm.shape)
    print ('1y_pred_train_lstm = ',y_pred_train_lstm.shape)
    print ('1y_pred_test_lstm = ',y_pred_test_lstm.shape)
    print ('1y_test_lstm = ',y_test_lstm.shape)
    
    # Inverse transform the scaled data to get the original scale
    y_pred_train_lstm = scaler.inverse_transform(y_pred_train_lstm)
    y_pred_test_lstm = scaler.inverse_transform(y_pred_test_lstm)
    y_train_lstm = scaler.inverse_transform(y_train_lstm)
    y_test_lstm = scaler.inverse_transform(y_test_lstm)

    print ('2y_pred_train_lstm = ',y_pred_train_lstm.shape)
    print ('2X_test_lstm = ',X_test_lstm.shape)
    print ('2y_pred_train_lstm = ',y_pred_train_lstm.shape)
    print ('2y_pred_test_lstm = ',y_pred_test_lstm.shape)
    print ('2y_test_lstm = ',y_test_lstm.shape)
    
    # Compute metrics for LSTM
    train_rmse = np.sqrt(mean_squared_error(y_train_lstm, y_pred_train_lstm))
    test_rmse = np.sqrt(mean_squared_error(y_test_lstm, y_pred_test_lstm))
    train_mse = mean_squared_error(y_train_lstm, y_pred_train_lstm)
    test_mse = mean_squared_error(y_test_lstm, y_pred_test_lstm)
    train_mae = mean_absolute_error(y_train_lstm, y_pred_train_lstm)
    test_mae = mean_absolute_error(y_test_lstm, y_pred_test_lstm)
    train_r2 = r2_score(y_train_lstm, y_pred_train_lstm)
    test_r2 = r2_score(y_test_lstm, y_pred_test_lstm)

    print("Train RMSE:", train_rmse)
    print("Train MSE:", train_mse)
    print("Train MAE:", train_mae)
    print("Train R2 Score:", train_r2)
    print("Test RMSE:", test_rmse)
    print("Test MSE:", test_mse)
    print("Test MAE:", test_mae)
    print("Test R2 Score:", test_r2)
    
    # Calculate residuals
    residuals = y_test_lstm - y_pred_test_lstm
    
    # Plot loss versus epoch and validation loss versus epoch
    plt.figure(figsize=(10, 5))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss from history')
    plt.title('Loss vs. Epoch')
    plt.legend()
    plt.show()
    
    # Create a residual plot
    plt.figure(figsize=(10, 5))
    plt.scatter(y_test_lstm, residuals, color='blue', alpha=0.6)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.xlabel('True Values')
    plt.ylabel('Residuals')
    plt.title(main_target)
    plt.show()
    
    # Plot actual vs. predicted values
    plt.figure(figsize=(10, 8))
    plt.scatter(y_test_lstm, y_pred_test_lstm, label='', color='blue')
    plt.plot([y_test_lstm.min(), y_test_lstm.max()], [y_test_lstm.min(), y_test_lstm.max()], 'k--', lw=2, label='')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(main_target)
    plt.show()
    
    # Plot actual, train data, and predicted test data for LSTM
    plt.figure(figsize=(15, 5))
    train_index = dfs_resampled.index[:train_size][-len(y_train_lstm):]
    test_index = dfs_resampled.index[train_size:]
    #plt.plot(dfs_resampled.index, dfs_resampled[target], label='Historical Data', color='gray')
    plt.plot(train_index, y_train_lstm, label='Train Data', color='blue')
    plt.plot(test_index, y_test_lstm, label='Test Data', color='#1f76b4')
    plt.plot(test_index, y_pred_test_lstm, label='Predicted Test Data', color='red')
    plt.plot(train_index, y_pred_train_lstm, label='Predicted Train Data', color='green', linestyle='dashed')
    plt.legend()
    plt.xticks([])
    plt.title(main_target)
    plt.ylabel(target_label)
    plt.xlabel('Date')
    plt.show()

      
    # Plot actual, train data, and predicted test data for LSTM
    plt.figure(figsize=(15, 5))
    train_index = dfs_resampled.index[:train_size][-len(y_train_lstm):]
    test_index = dfs_resampled.index[train_size:]
 #  plt.plot(dfs_resampled.index, dfs_resampled[target], label='Historical Data', color='gray')
 #  plt.plot(train_index, y_train_lstm, label='Train Data', color='blue')
    plt.plot(test_index, y_test_lstm, label='Test Data', color='#1f76b4')
    plt.plot(test_index, y_pred_test_lstm, label='Predicted Test Data', color='red')
 #  plt.plot(train_index, y_pred_train_lstm, label='Predicted Train Data', color='green', linestyle='dashed')
    plt.legend()
    plt.xticks([])
    plt.title(main_target)
    plt.ylabel(target_label)
    plt.xlabel('Date')
    plt.show()
    print(model.summary())

    print('X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape, X_lstm.shape, y_lstm.shape, dfs_resampled.shape =', X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape, X_lstm.shape, y_lstm.shape, dfs_resampled.shape)

    return {
        'train_rmse': train_rmse,
        'train_mse': train_mse,
        'train_mae': train_mae,
        'train_r2': train_r2,
        'test_rmse': test_rmse,
        'test_mse': test_mse,
        'test_mae': test_mae,
        'test_r2': test_r2,
        'residuals': residuals,
        'y_test_predicted': y_pred_test_lstm,
    }

# %%
 lookback=2
results = lstm_model('Solar_gwh', data_df, lookback, sampling_frequency=None)
# Out:
# data_df_shape, data_scaled_shape, X_lstm_shape, y_lstm_shape, X_lstm_shape[0]+X_lstm_shape[1]= (102, 12) (102, 1) (100, 2, 1) (100, 1) 102
# X_train_lstm_shape, X_test_lstm_shape, y_train_lstm_shape, y_test_lstm_shape = (80, 2, 1) (22, 2, 1) (80, 1) (22, 1)
# Epoch 1/100
# 3/3 [==============================] - 1s 98ms/step - loss: 0.1814 - val_loss: 0.3021
# Epoch 2/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1706 - val_loss: 0.2881
# Epoch 3/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1602 - val_loss: 0.2708
# Epoch 4/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1466 - val_loss: 0.2501
# Epoch 5/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1320 - val_loss: 0.2255
# Epoch 6/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1143 - val_loss: 0.1964
# Epoch 7/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0928 - val_loss: 0.1634
# Epoch 8/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0735 - val_loss: 0.1284
# Epoch 9/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0517 - val_loss: 0.0973
# Epoch 10/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0411 - val_loss: 0.0775
# Epoch 11/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0406 - val_loss: 0.0744
# Epoch 12/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0460 - val_loss: 0.0741
# Epoch 13/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0444 - val_loss: 0.0732
# Epoch 14/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0383 - val_loss: 0.0759
# Epoch 15/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0375 - val_loss: 0.0815
# Epoch 16/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0373 - val_loss: 0.0843
# Epoch 17/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0377 - val_loss: 0.0836
# Epoch 18/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0369 - val_loss: 0.0804
# Epoch 19/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0358 - val_loss: 0.0760
# Epoch 20/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0355 - val_loss: 0.0724
# Epoch 21/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0354 - val_loss: 0.0707
# Epoch 22/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0352 - val_loss: 0.0704
# Epoch 23/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0345 - val_loss: 0.0712
# Epoch 24/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0340 - val_loss: 0.0728
# Epoch 25/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0339 - val_loss: 0.0737
# Epoch 26/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0342 - val_loss: 0.0733
# Epoch 27/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0335 - val_loss: 0.0712
# Epoch 28/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0332 - val_loss: 0.0691
# Epoch 29/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0330 - val_loss: 0.0681
# Epoch 30/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0330 - val_loss: 0.0674
# Epoch 31/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0328 - val_loss: 0.0676
# Epoch 32/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0324 - val_loss: 0.0681
# Epoch 33/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0323 - val_loss: 0.0687
# Epoch 34/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0323 - val_loss: 0.0687
# Epoch 35/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0320 - val_loss: 0.0672
# Epoch 36/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0318 - val_loss: 0.0659
# Epoch 37/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0315 - val_loss: 0.0656
# Epoch 38/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0313 - val_loss: 0.0649
# Epoch 39/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0309 - val_loss: 0.0642
# Epoch 40/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0307 - val_loss: 0.0635
# Epoch 41/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0304 - val_loss: 0.0634
# Epoch 42/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0301 - val_loss: 0.0629
# Epoch 43/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0298 - val_loss: 0.0623
# Epoch 44/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0295 - val_loss: 0.0610
# Epoch 45/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0291 - val_loss: 0.0604
# Epoch 46/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0287 - val_loss: 0.0595
# Epoch 47/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0283 - val_loss: 0.0586
# Epoch 48/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0278 - val_loss: 0.0569
# Epoch 49/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0274 - val_loss: 0.0559
# Epoch 50/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0268 - val_loss: 0.0543
# Epoch 51/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0264 - val_loss: 0.0534
# Epoch 52/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0260 - val_loss: 0.0518
# Epoch 53/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0251 - val_loss: 0.0511
# Epoch 54/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0246 - val_loss: 0.0503
# Epoch 55/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0238 - val_loss: 0.0479
# Epoch 56/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0231 - val_loss: 0.0455
# Epoch 57/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0223 - val_loss: 0.0438
# Epoch 58/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0216 - val_loss: 0.0418
# Epoch 59/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0206 - val_loss: 0.0412
# Epoch 60/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0198 - val_loss: 0.0387
# Epoch 61/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0192 - val_loss: 0.0355
# Epoch 62/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0179 - val_loss: 0.0341
# Epoch 63/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0169 - val_loss: 0.0314
# Epoch 64/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0161 - val_loss: 0.0286
# Epoch 65/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0150 - val_loss: 0.0276
# Epoch 66/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0142 - val_loss: 0.0256
# Epoch 67/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0134 - val_loss: 0.0235
# Epoch 68/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0124 - val_loss: 0.0207
# Epoch 69/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0118 - val_loss: 0.0195
# Epoch 70/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0110 - val_loss: 0.0191
# Epoch 71/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0108 - val_loss: 0.0174
# Epoch 72/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0105 - val_loss: 0.0170
# Epoch 73/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0103 - val_loss: 0.0159
# Epoch 74/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0104 - val_loss: 0.0172
# Epoch 75/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0096 - val_loss: 0.0158
# Epoch 76/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0100 - val_loss: 0.0158
# Epoch 77/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0094 - val_loss: 0.0176
# Epoch 78/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0101 - val_loss: 0.0165
# Epoch 79/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0096 - val_loss: 0.0157
# Epoch 80/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0094 - val_loss: 0.0158
# Epoch 81/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0093 - val_loss: 0.0158
# Epoch 82/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0096 - val_loss: 0.0156
# Epoch 83/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0093 - val_loss: 0.0164
# Epoch 84/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0100 - val_loss: 0.0155
# Epoch 85/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0092 - val_loss: 0.0157
# Epoch 86/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0094 - val_loss: 0.0161
# Epoch 87/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0097 - val_loss: 0.0174
# Epoch 88/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0095 - val_loss: 0.0159
# Epoch 89/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0108 - val_loss: 0.0154
# Epoch 90/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0098 - val_loss: 0.0195
# Epoch 91/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0101 - val_loss: 0.0153
# Epoch 92/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0092 - val_loss: 0.0165
# Epoch 93/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0097 - val_loss: 0.0155
# Epoch 94/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0090 - val_loss: 0.0187
# Epoch 95/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0098 - val_loss: 0.0154
# Epoch 96/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0092 - val_loss: 0.0163
# Epoch 97/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0096 - val_loss: 0.0153
# Epoch 98/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0092 - val_loss: 0.0164
# Epoch 99/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0091 - val_loss: 0.0150
# Epoch 100/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0088 - val_loss: 0.0153
# Model: "sequential_123"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_246 (LSTM)             (None, 2, 256)            264192
#
#  lstm_247 (LSTM)             (None, 128)               197120
#
#  dense_124 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 461441 (1.76 MB)
# Trainable params: 461441 (1.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 3/3 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1y_pred_train_lstm =  (80, 1)
# 1X_test_lstm =  (22, 2, 1)
# 1y_pred_train_lstm =  (80, 1)
# 1y_pred_test_lstm =  (22, 1)
# 1y_test_lstm =  (22, 1)
# 2y_pred_train_lstm =  (80, 1)
# 2X_test_lstm =  (22, 2, 1)
# 2y_pred_train_lstm =  (80, 1)
# 2y_pred_test_lstm =  (22, 1)
# 2y_test_lstm =  (22, 1)
# Train RMSE: 778.8516021094954
# Train MSE: 606609.8181085277
# Train MAE: 635.92452008667
# Train R2 Score: 0.8344412746014115
# Test RMSE: 1020.6598782670068
# Test MSE: 1041746.587104021
# Test MAE: 823.8961984419391
# Test R2 Score: 0.8541012277668774
# Model: "sequential_123"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_246 (LSTM)             (None, 2, 256)            264192
#
#  lstm_247 (LSTM)             (None, 128)               197120
#
#  dense_124 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 461441 (1.76 MB)
# Trainable params: 461441 (1.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape, X_lstm.shape, y_lstm.shape, dfs_resampled.shape = (80, 2, 1) (22, 2, 1) (80, 1) (22, 1) (100, 2, 1) (100, 1) (102, 12)

# %%
#['Dt_date', 'Solar_gwh', 'Total_energy_generation_gwh','Wind_offshore_gwh', 'Wind_onshore_gwh', 'Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute',
#       'Mean_precipitation_de_mm', 'Spot_market_price_eur_per_gwh','Co2_emission_allowances_auction_eur_per_tco2']
lookback=15
results = lstm_model('Total_energy_generation_gwh', data_df, lookback, sampling_frequency=None)
# Out:
# data_df_shape, data_scaled_shape, X_lstm_shape, y_lstm_shape, X_lstm_shape[0]+X_lstm_shape[1]= (102, 12) (102, 1) (87, 15, 1) (87, 1) 102
# X_train_lstm_shape, X_test_lstm_shape, y_train_lstm_shape, y_test_lstm_shape = (69, 15, 1) (33, 15, 1) (69, 1) (33, 1)
# Epoch 1/100
# 3/3 [==============================] - 2s 113ms/step - loss: 0.3413 - val_loss: 0.1630
# Epoch 2/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2222 - val_loss: 0.0742
# Epoch 3/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0830 - val_loss: 0.0442
# Epoch 4/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0517 - val_loss: 0.0408
# Epoch 5/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0320 - val_loss: 0.0333
# Epoch 6/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0398 - val_loss: 0.0352
# Epoch 7/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0401 - val_loss: 0.0320
# Epoch 8/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0305 - val_loss: 0.0382
# Epoch 9/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0324 - val_loss: 0.0422
# Epoch 10/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0326 - val_loss: 0.0339
# Epoch 11/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0303 - val_loss: 0.0321
# Epoch 12/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0310 - val_loss: 0.0326
# Epoch 13/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0292 - val_loss: 0.0354
# Epoch 14/100
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0300 - val_loss: 0.0368
# Epoch 15/100
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0295 - val_loss: 0.0337
# Epoch 16/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0285 - val_loss: 0.0318
# Epoch 17/100
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0296 - val_loss: 0.0315
# Epoch 18/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0287 - val_loss: 0.0336
# Epoch 19/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0299 - val_loss: 0.0355
# Epoch 20/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0295 - val_loss: 0.0310
# Epoch 21/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0283 - val_loss: 0.0311
# Epoch 22/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0277 - val_loss: 0.0325
# Epoch 23/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0270 - val_loss: 0.0325
# Epoch 24/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0267 - val_loss: 0.0307
# Epoch 25/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0259 - val_loss: 0.0294
# Epoch 26/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0274 - val_loss: 0.0291
# Epoch 27/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0256 - val_loss: 0.0309
# Epoch 28/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0247 - val_loss: 0.0297
# Epoch 29/100
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0238 - val_loss: 0.0278
# Epoch 30/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0234 - val_loss: 0.0271
# Epoch 31/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0225 - val_loss: 0.0269
# Epoch 32/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0220 - val_loss: 0.0265
# Epoch 33/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0201 - val_loss: 0.0249
# Epoch 34/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0233 - val_loss: 0.0238
# Epoch 35/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0192 - val_loss: 0.0266
# Epoch 36/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0214 - val_loss: 0.0243
# Epoch 37/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0221 - val_loss: 0.0235
# Epoch 38/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0219 - val_loss: 0.0222
# Epoch 39/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0226 - val_loss: 0.0228
# Epoch 40/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0182 - val_loss: 0.0251
# Epoch 41/100
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0201 - val_loss: 0.0239
# Epoch 42/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0197 - val_loss: 0.0214
# Epoch 43/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0167 - val_loss: 0.0215
# Epoch 44/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0172 - val_loss: 0.0218
# Epoch 45/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0163 - val_loss: 0.0202
# Epoch 46/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0158 - val_loss: 0.0201
# Epoch 47/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0146 - val_loss: 0.0202
# Epoch 48/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0149 - val_loss: 0.0194
# Epoch 49/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0151 - val_loss: 0.0248
# Epoch 50/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0224 - val_loss: 0.0193
# Epoch 51/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0202 - val_loss: 0.0255
# Epoch 52/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0215 - val_loss: 0.0212
# Epoch 53/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0186 - val_loss: 0.0211
# Epoch 54/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0182 - val_loss: 0.0245
# Epoch 55/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0176 - val_loss: 0.0221
# Epoch 56/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0194 - val_loss: 0.0248
# Epoch 57/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0189 - val_loss: 0.0201
# Epoch 58/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0163 - val_loss: 0.0202
# Epoch 59/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0143 - val_loss: 0.0222
# Epoch 60/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0170 - val_loss: 0.0199
# Epoch 61/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0155 - val_loss: 0.0201
# Epoch 62/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0147 - val_loss: 0.0223
# Epoch 63/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0163 - val_loss: 0.0196
# Epoch 64/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0165 - val_loss: 0.0201
# Epoch 65/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0163 - val_loss: 0.0210
# Epoch 66/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0152 - val_loss: 0.0192
# Epoch 67/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0151 - val_loss: 0.0205
# Epoch 68/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0177 - val_loss: 0.0192
# Epoch 69/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0170 - val_loss: 0.0218
# Epoch 70/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0143 - val_loss: 0.0211
# Epoch 71/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0187 - val_loss: 0.0204
# Epoch 72/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0149 - val_loss: 0.0199
# Epoch 73/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0148 - val_loss: 0.0195
# Epoch 74/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0139 - val_loss: 0.0193
# Epoch 75/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0136 - val_loss: 0.0201
# Epoch 76/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0146 - val_loss: 0.0191
# Epoch 77/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0143 - val_loss: 0.0198
# Epoch 78/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0151 - val_loss: 0.0192
# Epoch 79/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0128 - val_loss: 0.0214
# Epoch 80/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0149 - val_loss: 0.0190
# Epoch 81/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0142 - val_loss: 0.0196
# Epoch 82/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0141 - val_loss: 0.0201
# Epoch 83/100
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0140 - val_loss: 0.0188
# Epoch 84/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0134 - val_loss: 0.0218
# Epoch 85/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0149 - val_loss: 0.0189
# Epoch 86/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0129 - val_loss: 0.0187
# Epoch 87/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0132 - val_loss: 0.0203
# Epoch 88/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0145 - val_loss: 0.0192
# Epoch 89/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0130 - val_loss: 0.0187
# Epoch 90/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0127 - val_loss: 0.0216
# Epoch 91/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0146 - val_loss: 0.0190
# Epoch 92/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0128 - val_loss: 0.0185
# Epoch 93/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0138 - val_loss: 0.0191
# Epoch 94/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0131 - val_loss: 0.0184
# Epoch 95/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0137 - val_loss: 0.0193
# Epoch 96/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0145 - val_loss: 0.0190
# Epoch 97/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0143 - val_loss: 0.0199
# Epoch 98/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0151 - val_loss: 0.0201
# Epoch 99/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0133 - val_loss: 0.0185
# Epoch 100/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0143 - val_loss: 0.0197
# Model: "sequential_124"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_248 (LSTM)             (None, 15, 256)           264192
#
#  lstm_249 (LSTM)             (None, 128)               197120
#
#  dense_125 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 461441 (1.76 MB)
# Trainable params: 461441 (1.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 3/3 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 2ms/step
# 1y_pred_train_lstm =  (69, 1)
# 1X_test_lstm =  (33, 15, 1)
# 1y_pred_train_lstm =  (69, 1)
# 1y_pred_test_lstm =  (33, 1)
# 1y_test_lstm =  (33, 1)
# 2y_pred_train_lstm =  (69, 1)
# 2X_test_lstm =  (33, 15, 1)
# 2y_pred_train_lstm =  (69, 1)
# 2y_pred_test_lstm =  (33, 1)
# 2y_test_lstm =  (33, 1)
# Train RMSE: 2322.637192340045
# Train MSE: 5394643.527241249
# Train MAE: 1824.6026870471012
# Train R2 Score: 0.6326333653279603
# Test RMSE: 2881.478088738539
# Test MSE: 8302915.975880303
# Test MAE: 2472.639426136364
# Test R2 Score: 0.41631704974237305
# Model: "sequential_124"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_248 (LSTM)             (None, 15, 256)           264192
#
#  lstm_249 (LSTM)             (None, 128)               197120
#
#  dense_125 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 461441 (1.76 MB)
# Trainable params: 461441 (1.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape, X_lstm.shape, y_lstm.shape, dfs_resampled.shape = (69, 15, 1) (33, 15, 1) (69, 1) (33, 1) (87, 15, 1) (87, 1) (102, 12)

# %% [markdown]
# ##  Multivariate LSTM

# %%
def create_sequences(data, target, lookback):
    X, y = [], []
    for i in range(len(data) - lookback):
        X.append(data[i:i+lookback, :-1])  # Features
        y.append(data[i+lookback-1, -1])   # Target
    return np.array(X), np.array(y)

def lstm_mlvt_model(target, data_mlvt, features, lookback):
    dfs = data_mlvt[['Date'] + features + [target]]
    dfs['Date'] = pd.to_datetime(dfs['Date'])
    dfs.set_index('Date', inplace=True)

    # Separate target and features
    target_data = dfs[[target]].values
    feature_data = dfs[features].values

    # Scale features and target separately
    scaler_features = MinMaxScaler(feature_range=(0, 1))
    scaler_target = MinMaxScaler(feature_range=(0, 1))

    feature_scaled = scaler_features.fit_transform(feature_data)
    target_scaled = scaler_target.fit_transform(target_data)

    # Create sequences with scaled data
    data_scaled = np.hstack((feature_scaled, target_scaled))
    X_lstm, y_lstm = create_sequences(data_scaled, target_scaled, lookback)  # Pass target_scaled to create_sequences


    print('data_mlvt_shape, data_scaled_shape, X_lstm_shape, y_lstm_shape, X_lstm_shape[0]+X_lstm_shape[1]=',data_mlvt.shape, data_scaled.shape, X_lstm.shape, y_lstm.shape, X_lstm.shape[0]+X_lstm.shape[1])
    print('X_lstm_shape, X_lstm_shape, y_lstm_shape, y_lstm_shape =',X_lstm.shape, X_lstm.shape, y_lstm.shape, y_lstm.shape)



    # Build the LSTM model
    model = Sequential()
    model.add(LSTM(units=64, activation='relu', input_shape=(lookback, len(features)), return_sequences=True))
    model.add(LSTM(units=32, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(X_lstm, y_lstm, epochs=100, batch_size=30, validation_split=0.2, verbose=1)

    # LSTM prediction on test and train data
    y_pred_lstm = model.predict(X_lstm)

    # Reshape y_pred_lstm to 1-dimensional array
    y_pred_lstm = y_pred_lstm.reshape(-1)

    # Inverse transform the scaled data to get the original scale
    y_pred_lstm = scaler_target.inverse_transform(y_pred_lstm.reshape(-1, 1)).flatten()
    y_lstm = scaler_target.inverse_transform(y_lstm.reshape(-1, 1)).flatten()

    # Calculate residuals
    residuals = y_lstm - y_pred_lstm

    # Print shapes after inverse transform
    print("Shapes after inverse transform:")
    print("y_pred_lstm shape:", y_pred_lstm.shape)
    print("y_lstm shape:", y_lstm.shape)

    # Calculate metrics
    mse = mean_squared_error(y_lstm, y_pred_lstm)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_lstm, y_pred_lstm)
    r2 = r2_score(y_lstm, y_pred_lstm)

    # Print metrics
    print("Mean Squared Error (MSE):", mse)
    print("Root Mean Squared Error (RMSE):", rmse)
    print("Mean Absolute Error (MAE):", mae)
    print("R-squared (R^2) Score:", r2)

    # Plot loss versus epoch and validation loss versus epoch
    plt.figure(figsize=(10, 5))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss vs. Epoch')
    plt.legend()
    plt.show()

    # Create a residual plot
    plt.figure(figsize=(10, 5))
    plt.scatter(y_lstm, residuals, color='blue', alpha=0.6)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.xlabel('True Values')
    plt.ylabel('Residuals')
    plt.title(target)

    plt.figure(figsize=(10, 8))
    plt.scatter(y_lstm, y_pred_lstm, label='Actual vs. Predicted', color='blue', alpha=0.7)
    plt.plot([y_lstm.min(), y_lstm.max()], [y_lstm.min(), y_lstm.max()], 'k--', lw=2, label='Ideal')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Actual vs. Predicted Values')
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.show()



    # Plot actual vs. predicted values with time (including test data only)
    test_index = dfs.index[-len(y_lstm):]
    plt.figure(figsize=(10, 8))
    plt.plot(test_index, y_lstm, label='Test Data', color='#1f76b4')
    plt.plot(test_index, y_pred_lstm, label='Predicted Test Data', color='red')
    plt.legend()
    plt.xticks([])
    plt.title(target)
    plt.ylabel(target)
    plt.xlabel('Date')
    plt.show()
    print(model.summary())
 #   # Plot actual vs. predicted values with time
 #   plt.figure(figsize=(10, 8))
 #   plt.scatter(dfs.index[-len(y_lstm):], y_lstm, label='True Values', color='blue')
 #   plt.scatter(dfs.index[-len(y_pred_lstm):], y_pred_lstm, label='Predicted Values', color='orange')
 #   plt.xlabel('Date')
 #   plt.ylabel(target)
 #   plt.title(target)
 #   plt.legend()
 #   plt.show()

# %%
columns_mlvt= ['Date','Mean_sunshine_duration_de_minute', 'Mean_air_temperature_de_c', 'Mean_precipitation_de_mm', 'Solar_gwh'] #'Total_other_renewable_gwh'
#target = 'Total_energy_generation_gwh'
data_mlvt = data_df[columns_mlvt].copy()
#data_mlvt.head()

# %%
#print(data_mlvt.isnull().sum())
data_mlvt.shape, 72+30
# Out:
# ((102, 5), 102)

# %%
#data = data_df.copy()
#target = 'Total_energy_generation_gwh'
features = ['Mean_sunshine_duration_de_minute', 'Mean_air_temperature_de_c', 'Mean_precipitation_de_mm']
target = 'Solar_gwh'
lookback = 12
#features =  ['Mean_sunshine_duration_de_minute']#['Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute', 'Mean_precipitation_de_mm']
lstm_mlvt_model(target, data_mlvt, features, lookback)
# Out:
# data_mlvt_shape, data_scaled_shape, X_lstm_shape, y_lstm_shape, X_lstm_shape[0]+X_lstm_shape[1]= (102, 5) (102, 4) (90, 12, 3) (90,) 102
# X_lstm_shape, X_lstm_shape, y_lstm_shape, y_lstm_shape = (90, 12, 3) (90, 12, 3) (90,) (90,)
# Epoch 1/100
# 3/3 [==============================] - 2s 115ms/step - loss: 0.1609 - val_loss: 0.2552
# Epoch 2/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1370 - val_loss: 0.2212
# Epoch 3/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1126 - val_loss: 0.1836
# Epoch 4/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0859 - val_loss: 0.1447
# Epoch 5/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0714 - val_loss: 0.1191
# Epoch 6/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0633 - val_loss: 0.1141
# Epoch 7/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0665 - val_loss: 0.1127
# Epoch 8/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0661 - val_loss: 0.1135
# Epoch 9/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0629 - val_loss: 0.1173
# Epoch 10/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0605 - val_loss: 0.1189
# Epoch 11/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0597 - val_loss: 0.1183
# Epoch 12/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0587 - val_loss: 0.1154
# Epoch 13/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0573 - val_loss: 0.1116
# Epoch 14/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0558 - val_loss: 0.1061
# Epoch 15/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0541 - val_loss: 0.1018
# Epoch 16/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0526 - val_loss: 0.0994
# Epoch 17/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0502 - val_loss: 0.1017
# Epoch 18/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0479 - val_loss: 0.0994
# Epoch 19/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0449 - val_loss: 0.0902
# Epoch 20/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0419 - val_loss: 0.0765
# Epoch 21/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0384 - val_loss: 0.0766
# Epoch 22/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0330 - val_loss: 0.0755
# Epoch 23/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0286 - val_loss: 0.0660
# Epoch 24/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0234 - val_loss: 0.0602
# Epoch 25/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0193 - val_loss: 0.0569
# Epoch 26/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0473
# Epoch 27/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0171 - val_loss: 0.0727
# Epoch 28/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0160 - val_loss: 0.0397
# Epoch 29/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0139 - val_loss: 0.0624
# Epoch 30/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0173 - val_loss: 0.0760
# Epoch 31/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0129 - val_loss: 0.0289
# Epoch 32/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0139 - val_loss: 0.0450
# Epoch 33/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0105 - val_loss: 0.0609
# Epoch 34/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0103 - val_loss: 0.0395
# Epoch 35/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0085 - val_loss: 0.0357
# Epoch 36/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0073 - val_loss: 0.0488
# Epoch 37/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0075 - val_loss: 0.0453
# Epoch 38/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0314
# Epoch 39/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0461
# Epoch 40/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 0.0420
# Epoch 41/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 0.0409
# Epoch 42/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0508
# Epoch 43/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0301
# Epoch 44/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0444
# Epoch 45/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0054 - val_loss: 0.0492
# Epoch 46/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0054 - val_loss: 0.0324
# Epoch 47/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0057 - val_loss: 0.0377
# Epoch 48/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0440
# Epoch 49/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0386
# Epoch 50/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0437
# Epoch 51/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 0.0360
# Epoch 52/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 0.0427
# Epoch 53/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0411
# Epoch 54/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0373
# Epoch 55/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0430
# Epoch 56/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0042 - val_loss: 0.0294
# Epoch 57/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0055 - val_loss: 0.0398
# Epoch 58/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0041 - val_loss: 0.0407
# Epoch 59/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0042 - val_loss: 0.0353
# Epoch 60/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0370
# Epoch 61/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0039 - val_loss: 0.0282
# Epoch 62/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 0.0495
# Epoch 63/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0051 - val_loss: 0.0321
# Epoch 64/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0357
# Epoch 65/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 0.0464
# Epoch 66/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 0.0236
# Epoch 67/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0404
# Epoch 68/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 0.0387
# Epoch 69/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0038 - val_loss: 0.0274
# Epoch 70/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0041 - val_loss: 0.0374
# Epoch 71/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 0.0295
# Epoch 72/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0034 - val_loss: 0.0380
# Epoch 73/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0340
# Epoch 74/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0033 - val_loss: 0.0301
# Epoch 75/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 0.0389
# Epoch 76/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 0.0347
# Epoch 77/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 0.0325
# Epoch 78/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 0.0350
# Epoch 79/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 0.0349
# Epoch 80/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 0.0293
# Epoch 81/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0340
# Epoch 82/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 0.0335
# Epoch 83/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0341
# Epoch 84/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0286
# Epoch 85/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0297
# Epoch 86/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0309
# Epoch 87/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 0.0309
# Epoch 88/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 0.0344
# Epoch 89/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0278
# Epoch 90/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0315
# Epoch 91/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 0.0356
# Epoch 92/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0266
# Epoch 93/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 0.0301
# Epoch 94/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0027 - val_loss: 0.0281
# Epoch 95/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 0.0313
# Epoch 96/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 0.0217
# Epoch 97/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0034 - val_loss: 0.0341
# Epoch 98/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 0.0294
# Epoch 99/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0026 - val_loss: 0.0284
# Epoch 100/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0029 - val_loss: 0.0300
# 3/3 [==============================] - 0s 2ms/step
# Shapes after inverse transform:
# y_pred_lstm shape: (90,)
# y_lstm shape: (90,)
# Mean Squared Error (MSE): 544568.3780343153
# Root Mean Squared Error (RMSE): 737.948763827351
# Mean Absolute Error (MAE): 465.4783740180121
# R-squared (R^2) Score: 0.8831569399065372

# %%
columns_mlvt= ['Date','Mean_air_temperature_de_c', 'Mean_precipitation_de_mm', 'Solar_gwh'] #'Total_other_renewable_gwh'
#target = 'Total_energy_generation_gwh'
data_mlvt = data_df[columns_mlvt].copy()
data_mlvt.head()
# Out:
#         Date  Mean_air_temperature_de_c  Mean_precipitation_de_mm   Solar_gwh
# 0 2015-01-01                       2.19                      85.4   559.67350
# 1 2015-02-01                       0.72                      22.3  1371.00425
# 2 2015-03-01                       5.18                      55.5  2858.57725
# 3 2015-04-01                       8.42                      41.4  4435.38900
# 4 2015-05-01                      12.34                      51.7  4411.59000

# %%
#data = data_df.copy()
#target = 'Total_energy_generation_gwh'
features = ['Mean_air_temperature_de_c', 'Mean_precipitation_de_mm']
target = 'Solar_gwh'
lookback = 12
#features =  ['Mean_sunshine_duration_de_minute']#['Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute', 'Mean_precipitation_de_mm']
lstm_mlvt_model(target, data_mlvt, features, lookback)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 112ms/step - loss: 0.1742 - val_loss: 0.2620
# Epoch 2/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1382 - val_loss: 0.2146
# Epoch 3/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1033 - val_loss: 0.1665
# Epoch 4/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0783 - val_loss: 0.1276
# Epoch 5/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0650 - val_loss: 0.1110
# Epoch 6/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0644 - val_loss: 0.1091
# Epoch 7/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0646 - val_loss: 0.1112
# Epoch 8/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0607 - val_loss: 0.1176
# Epoch 9/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0592 - val_loss: 0.1228
# Epoch 10/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0600 - val_loss: 0.1249
# Epoch 11/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0596 - val_loss: 0.1197
# Epoch 12/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0573 - val_loss: 0.1125
# Epoch 13/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0543 - val_loss: 0.1041
# Epoch 14/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0554 - val_loss: 0.0975
# Epoch 15/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0517 - val_loss: 0.1023
# Epoch 16/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0496 - val_loss: 0.1037
# Epoch 17/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0471 - val_loss: 0.0951
# Epoch 18/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0429 - val_loss: 0.0841
# Epoch 19/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0398 - val_loss: 0.0751
# Epoch 20/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0365 - val_loss: 0.0753
# Epoch 21/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0313 - val_loss: 0.0823
# Epoch 22/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0284 - val_loss: 0.0632
# Epoch 23/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0277 - val_loss: 0.0486
# Epoch 24/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0191 - val_loss: 0.0761
# Epoch 25/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0197 - val_loss: 0.0603
# Epoch 26/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0139 - val_loss: 0.0364
# Epoch 27/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0122 - val_loss: 0.0683
# Epoch 28/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0113 - val_loss: 0.0373
# Epoch 29/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0097 - val_loss: 0.0484
# Epoch 30/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0079 - val_loss: 0.0505
# Epoch 31/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0072 - val_loss: 0.0423
# Epoch 32/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0077 - val_loss: 0.0499
# Epoch 33/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0510
# Epoch 34/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0073 - val_loss: 0.0455
# Epoch 35/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0408
# Epoch 36/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0522
# Epoch 37/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0382
# Epoch 38/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0072 - val_loss: 0.0562
# Epoch 39/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0073 - val_loss: 0.0452
# Epoch 40/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.0383
# Epoch 41/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0590
# Epoch 42/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0448
# Epoch 43/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0092 - val_loss: 0.0438
# Epoch 44/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0074 - val_loss: 0.0666
# Epoch 45/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0354
# Epoch 46/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0077 - val_loss: 0.0507
# Epoch 47/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0080 - val_loss: 0.0560
# Epoch 48/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0325
# Epoch 49/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0570
# Epoch 50/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0073 - val_loss: 0.0525
# Epoch 51/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0064 - val_loss: 0.0345
# Epoch 52/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 0.0565
# Epoch 53/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 0.0486
# Epoch 54/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0397
# Epoch 55/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0422
# Epoch 56/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0419
# Epoch 57/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0487
# Epoch 58/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0059 - val_loss: 0.0420
# Epoch 59/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0054 - val_loss: 0.0487
# Epoch 60/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0055 - val_loss: 0.0418
# Epoch 61/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0054 - val_loss: 0.0408
# Epoch 62/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0055 - val_loss: 0.0435
# Epoch 63/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0055 - val_loss: 0.0439
# Epoch 64/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0055 - val_loss: 0.0452
# Epoch 65/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0053 - val_loss: 0.0402
# Epoch 66/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0053 - val_loss: 0.0435
# Epoch 67/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0056 - val_loss: 0.0464
# Epoch 68/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0052 - val_loss: 0.0383
# Epoch 69/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0054 - val_loss: 0.0460
# Epoch 70/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0058 - val_loss: 0.0482
# Epoch 71/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0052 - val_loss: 0.0353
# Epoch 72/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0060 - val_loss: 0.0491
# Epoch 73/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0069 - val_loss: 0.0494
# Epoch 74/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0277
# Epoch 75/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0057 - val_loss: 0.0574
# Epoch 76/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0526
# Epoch 77/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0056 - val_loss: 0.0238
# Epoch 78/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0071 - val_loss: 0.0554
# Epoch 79/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0068 - val_loss: 0.0485
# Epoch 80/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0050 - val_loss: 0.0313
# Epoch 81/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0054 - val_loss: 0.0485
# Epoch 82/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0062 - val_loss: 0.0500
# Epoch 83/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0048 - val_loss: 0.0260
# Epoch 84/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0070 - val_loss: 0.0468
# Epoch 85/100
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0054 - val_loss: 0.0485
# Epoch 86/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0048 - val_loss: 0.0282
# Epoch 87/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0061 - val_loss: 0.0417
# Epoch 88/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0053 - val_loss: 0.0502
# Epoch 89/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0314
# Epoch 90/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0054 - val_loss: 0.0395
# Epoch 91/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0046 - val_loss: 0.0429
# Epoch 92/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0044 - val_loss: 0.0320
# Epoch 93/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0055 - val_loss: 0.0404
# Epoch 94/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0051 - val_loss: 0.0487
# Epoch 95/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0051 - val_loss: 0.0295
# Epoch 96/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0459
# Epoch 97/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0057 - val_loss: 0.0490
# Epoch 98/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0284
# Epoch 99/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0052 - val_loss: 0.0429
# Epoch 100/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0405
# 3/3 [==============================] - 0s 3ms/step
# Shapes after inverse transform:
# y_pred_lstm shape: (90,)
# y_lstm shape: (90,)
# Mean Squared Error (MSE): 788968.6605892079
# Root Mean Squared Error (RMSE): 888.2390785082629
# Mean Absolute Error (MAE): 599.9051476806642
# R-squared (R^2) Score: 0.8307182048398801

# %% [markdown]
# #### Multivariate LSTM with test and train split

# %%
def create_sequences(data, target, lookback):
    X, y = [], []
    for i in range(len(data) - lookback):
        X.append(data[i:i + lookback, :-1])  # Features
        y.append(data[i + lookback - 1, -1])  # Target
    return np.array(X), np.array(y)

def lstm_mlvt_model_tst_trn(target, data_mlvt, features, lookback):
    dfs = data_mlvt[['Date'] + features + [target]]
    dfs['Date'] = pd.to_datetime(dfs['Date'])
    dfs.set_index('Date', inplace=True)

    # Separate target and features
    target_data = dfs[[target]].values
    feature_data = dfs[features].values

    # Apply MinMax scaling with rounding
    scaler_features = MinMaxScaler(feature_range=(0, 1))
    scaler_target = MinMaxScaler(feature_range=(0, 1))

    #feature_data_scaled = np.round(scaler_features.fit_transform(feature_data), 4)
    #target_data_scaled = np.round(scaler_target.fit_transform(target_data), 4)

    feature_data_scaled = scaler_features.fit_transform(feature_data)
    target_data_scaled = scaler_target.fit_transform(target_data)


    data_scaled = np.hstack((feature_data_scaled, target_data_scaled))

    X_lstm, y_lstm = create_sequences(data_scaled, target_data_scaled, lookback)

    model = Sequential()
    model.add(LSTM(units=64, activation='relu', input_shape=(lookback, len(features)), return_sequences=True))
    model.add(LSTM(units=32, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(X_lstm, y_lstm, epochs=100, batch_size=30, validation_split=0.2, verbose=1)

    y_pred_lstm = model.predict(X_lstm)

    y_pred_lstm = y_pred_lstm.reshape(-1)

    # Inverse transform the predicted and target values back to the original scale
    y_pred_lstm = scaler_target.inverse_transform(y_pred_lstm.reshape(-1, 1)).flatten()
    y_lstm = scaler_target.inverse_transform(y_lstm.reshape(-1, 1)).flatten()

    return y_lstm, y_pred_lstm

# %%
columns_mlvt= ['Date','Mean_air_temperature_de_c', 'Mean_precipitation_de_mm', 'Solar_gwh'] #'Total_other_renewable_gwh'
#target = 'Total_energy_generation_gwh'
data_mlvt = data_df[columns_mlvt].copy()
#data_mlvt.head()
#

# %%
data = data_df.copy()
#target = 'Total_energy_generation_gwh'
features = ['Mean_air_temperature_de_c', 'Mean_precipitation_de_mm']
target = 'Solar_gwh'
lookback = 12
#features =  ['Mean_sunshine_duration_de_minute']#['Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute', 'Mean_precipitation_de_mm']
lstm_mlvt_model_tst_trn(target, data_mlvt, features, lookback)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 123ms/step - loss: 0.1952 - val_loss: 0.2983
# Epoch 2/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1688 - val_loss: 0.2708
# Epoch 3/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1490 - val_loss: 0.2454
# Epoch 4/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1296 - val_loss: 0.2184
# Epoch 5/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1110 - val_loss: 0.1881
# Epoch 6/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0881 - val_loss: 0.1531
# Epoch 7/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0728 - val_loss: 0.1214
# Epoch 8/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0610 - val_loss: 0.1088
# Epoch 9/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0681 - val_loss: 0.1075
# Epoch 10/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0644 - val_loss: 0.1120
# Epoch 11/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0602 - val_loss: 0.1209
# Epoch 12/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0608 - val_loss: 0.1269
# Epoch 13/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0615 - val_loss: 0.1271
# Epoch 14/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0610 - val_loss: 0.1237
# Epoch 15/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0583 - val_loss: 0.1152
# Epoch 16/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0588 - val_loss: 0.1061
# Epoch 17/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0587 - val_loss: 0.1043
# Epoch 18/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0570 - val_loss: 0.1066
# Epoch 19/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0556 - val_loss: 0.1094
# Epoch 20/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0539 - val_loss: 0.1083
# Epoch 21/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0526 - val_loss: 0.1079
# Epoch 22/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0510 - val_loss: 0.1037
# Epoch 23/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0485 - val_loss: 0.0960
# Epoch 24/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0453 - val_loss: 0.0863
# Epoch 25/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0431 - val_loss: 0.0814
# Epoch 26/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0384 - val_loss: 0.0855
# Epoch 27/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0340 - val_loss: 0.0720
# Epoch 28/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0288 - val_loss: 0.0582
# Epoch 29/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0231 - val_loss: 0.0587
# Epoch 30/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0176 - val_loss: 0.0425
# Epoch 31/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0162 - val_loss: 0.0648
# Epoch 32/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0145 - val_loss: 0.0368
# Epoch 33/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0159 - val_loss: 0.0727
# Epoch 34/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0184 - val_loss: 0.0553
# Epoch 35/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0140 - val_loss: 0.0347
# Epoch 36/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0114 - val_loss: 0.0796
# Epoch 37/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0130 - val_loss: 0.0400
# Epoch 38/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0120 - val_loss: 0.0355
# Epoch 39/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0096 - val_loss: 0.0685
# Epoch 40/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0119 - val_loss: 0.0500
# Epoch 41/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0098 - val_loss: 0.0339
# Epoch 42/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0089 - val_loss: 0.0659
# Epoch 43/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0100 - val_loss: 0.0525
# Epoch 44/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0077 - val_loss: 0.0344
# Epoch 45/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0078 - val_loss: 0.0535
# Epoch 46/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0077 - val_loss: 0.0548
# Epoch 47/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0069 - val_loss: 0.0361
# Epoch 48/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0075 - val_loss: 0.0471
# Epoch 49/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0066 - val_loss: 0.0497
# Epoch 50/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0463
# Epoch 51/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0073 - val_loss: 0.0470
# Epoch 52/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0064 - val_loss: 0.0350
# Epoch 53/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0069 - val_loss: 0.0503
# Epoch 54/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0066 - val_loss: 0.0442
# Epoch 55/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0065 - val_loss: 0.0371
# Epoch 56/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0059 - val_loss: 0.0574
# Epoch 57/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0089 - val_loss: 0.0548
# Epoch 58/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0061 - val_loss: 0.0292
# Epoch 59/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0075 - val_loss: 0.0515
# Epoch 60/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0072 - val_loss: 0.0523
# Epoch 61/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0062 - val_loss: 0.0298
# Epoch 62/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0072 - val_loss: 0.0493
# Epoch 63/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0552
# Epoch 64/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 0.0332
# Epoch 65/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 0.0448
# Epoch 66/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0508
# Epoch 67/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0059 - val_loss: 0.0311
# Epoch 68/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0065 - val_loss: 0.0475
# Epoch 69/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0059 - val_loss: 0.0439
# Epoch 70/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0056 - val_loss: 0.0362
# Epoch 71/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 0.0444
# Epoch 72/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0056 - val_loss: 0.0409
# Epoch 73/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0055 - val_loss: 0.0367
# Epoch 74/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0455
# Epoch 75/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0411
# Epoch 76/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0402
# Epoch 77/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0519
# Epoch 78/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0059 - val_loss: 0.0342
# Epoch 79/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 0.0377
# Epoch 80/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0051 - val_loss: 0.0420
# Epoch 81/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0413
# Epoch 82/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0386
# Epoch 83/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 0.0419
# Epoch 84/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0325
# Epoch 85/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0054 - val_loss: 0.0384
# Epoch 86/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0475
# Epoch 87/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0055 - val_loss: 0.0362
# Epoch 88/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0056 - val_loss: 0.0344
# Epoch 89/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0504
# Epoch 90/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0058 - val_loss: 0.0352
# Epoch 91/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0353
# Epoch 92/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0385
# Epoch 93/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0375
# Epoch 94/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0321
# Epoch 95/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0051 - val_loss: 0.0397
# Epoch 96/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0351
# Epoch 97/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 0.0350
# Epoch 98/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0051 - val_loss: 0.0340
# Epoch 99/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0456
# Epoch 100/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0051 - val_loss: 0.0341
# 3/3 [==============================] - 0s 3ms/step
# (array([ 850.9295 ,  654.31425, 1257.14675, 2414.15325, 3751.5355 ,
#         4716.76525, 4741.3405 , 4942.8115 , 4719.89325, 3848.414  ,
#         1679.7355 , 1020.888  ,  791.9385 ,  798.42225, 1484.969  ,
#         3230.5985 , 3856.85375, 5120.31225, 5366.8605 , 4886.3395 ,
#         4602.78775, 3079.28725, 2130.3165 ,  831.0175 ,  495.41625,
#          730.14475, 1830.4995 , 2703.90975, 4837.04525, 5931.47875,
#         5337.322  , 6166.89875, 5183.46425, 4069.317  , 2748.584  ,
#         1170.9555 ,  524.6635 ,  745.0215 , 2191.26725, 3051.987  ,
#         5111.3625 , 5023.131  , 6454.292  , 5734.5835 , 5278.09275,
#         3914.1795 , 2429.00125, 1048.334  ,  933.518  , 1097.17575,
#         1671.17325, 4104.0725 , 6316.26875, 6196.537  , 5718.8275 ,
#         6284.324  , 5438.543  , 4629.77925, 2162.818  , 1517.03975,
#          685.01925,  612.89025, 1993.47775, 4133.17075, 5463.4095 ,
#         5897.5285 , 7126.3275 , 6245.02925, 5278.4955 , 4802.81025,
#         3221.2895 , 1114.24375,  718.21225,  975.1675 , 2233.2655 ,
#         5496.85025, 5590.521  , 7360.4025 , 7872.51125, 7903.871  ,
#         7286.87375, 4800.86875, 3560.05325, 1703.98925,  656.601  ,
#          854.822  , 2353.52225, 3754.48075, 5404.7945 , 7844.58425]),
#  array([ 591.2932 , 1004.238  , 1789.9026 , 3023.3667 , 4295.966  ,
#         5433.0605 , 6037.9653 , 5691.324  , 4627.0303 , 3823.1611 ,
#         2703.1562 , 1806.6018 ,  767.5986 ,  991.7801 , 1936.3657 ,
#         3117.7236 , 4399.377  , 5403.864  , 6027.0347 , 5850.4526 ,
#         4829.7773 , 3238.908  , 1830.8518 , 1018.40936,  668.72144,
#         1209.8405 , 2242.097  , 3486.2239 , 4974.992  , 6081.2    ,
#         6159.1226 , 6075.5664 , 5418.57   , 4463.8706 , 2255.3157 ,
#          998.097  ,  936.3973 , 1399.4457 , 2209.8054 , 3723.8398 ,
#         4892.644  , 5884.0415 , 6480.279  , 6088.188  , 5125.0923 ,
#         3998.5835 , 2301.2983 , 1107.374  ,  643.2581 , 1284.8647 ,
#         1963.8158 , 3369.8752 , 4472.6816 , 5764.316  , 5926.1704 ,
#         5616.0947 , 4761.804  , 3646.5347 , 2081.7595 , 1013.8016 ,
#          727.63   ,  948.86414, 2051.6282 , 3295.9568 , 4275.8994 ,
#         5408.558  , 6180.198  , 6062.39   , 5174.654  , 4200.763  ,
#         3142.867  , 1564.775  ,  989.17706, 1145.9366 , 2045.1726 ,
#         3149.0408 , 4116.4043 , 5409.287  , 5580.915  , 5181.8076 ,
#         4471.651  , 3199.627  , 1912.3746 ,  962.8319 ,  836.42444,
#         1281.4753 , 2461.465  , 3541.9753 , 5018.5454 , 6052.6094 ],
#        dtype=float32))

# %%
def create_sequences(data, target, lookback):
    X, y = [], []
    for i in range(len(data) - lookback):
        X.append(data[i:i + lookback, :-1])  # Features
        y.append(data[i + lookback - 1, -1])  # Target
    return np.array(X), np.array(y)

def lstm_mlvt_model1(target, data_mlvt, features, lookback, train_test_split):
    dfs = data_mlvt[['Date'] + features + [target]]
    dfs['Date'] = pd.to_datetime(dfs['Date'])
    dfs.set_index('Date', inplace=True)

    # Separate target and features
    target_data = dfs[[target]].values
    feature_data = dfs[features].values

    # Apply MinMax scaling with rounding
    scaler_features = MinMaxScaler(feature_range=(0, 1))
    scaler_target = MinMaxScaler(feature_range=(0, 1))

    feature_data_scaled = np.round(scaler_features.fit_transform(feature_data), 4)
    target_data_scaled = np.round(scaler_target.fit_transform(target_data), 4)

    data_scaled = np.hstack((feature_data_scaled, target_data_scaled))

    # Train-test split
    split_index = int(len(data_scaled) * train_test_split)
    train_data_scaled = data_scaled[:split_index]
    test_data_scaled = data_scaled[split_index:]

    X_train_lstm, y_train_lstm = create_sequences(train_data_scaled, target_data_scaled, lookback)
    X_test_lstm, y_test_lstm = create_sequences(test_data_scaled, target_data_scaled, lookback)

    model = Sequential()
    model.add(LSTM(units=64, activation='relu', input_shape=(lookback, len(features)), return_sequences=True))
    model.add(LSTM(units=32, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(X_train_lstm, y_train_lstm, epochs=100, batch_size=30, validation_split=0.2, verbose=1)

    y_train_pred_lstm = model.predict(X_train_lstm)
    y_test_pred_lstm = model.predict(X_test_lstm)

    y_train_pred_lstm = y_train_pred_lstm.reshape(-1)
    y_test_pred_lstm = y_test_pred_lstm.reshape(-1)

    # Inverse transform the predicted and target values back to the original scale
    y_train_pred_lstm = scaler_target.inverse_transform(y_train_pred_lstm.reshape(-1, 1)).flatten()
    y_train_lstm = scaler_target.inverse_transform(y_train_lstm.reshape(-1, 1)).flatten()

    y_test_pred_lstm = scaler_target.inverse_transform(y_test_pred_lstm.reshape(-1, 1)).flatten()
    y_test_lstm = scaler_target.inverse_transform(y_test_lstm.reshape(-1, 1)).flatten()

    # Calculate metrics for both training and testing sets
    train_mse = mean_squared_error(y_train_lstm, y_train_pred_lstm)
    train_rmse = np.sqrt(train_mse)
    train_mae = mean_absolute_error(y_train_lstm, y_train_pred_lstm)
    train_r2 = r2_score(y_train_lstm, y_train_pred_lstm)

    test_mse = mean_squared_error(y_test_lstm, y_test_pred_lstm)
    test_rmse = np.sqrt(test_mse)
    test_mae = mean_absolute_error(y_test_lstm, y_test_pred_lstm)
    test_r2 = r2_score(y_test_lstm, y_test_pred_lstm)

    # Print metrics for both training and testing sets
    print("Training Mean Squared Error (MSE):", train_mse)
    print("Training Root Mean Squared Error (RMSE):", train_rmse)
    print("Training Mean Absolute Error (MAE):", train_mae)
    print("Training R-squared (R^2) Score:", train_r2)

    print("Testing Mean Squared Error (MSE):", test_mse)
    print("Testing Root Mean Squared Error (RMSE):", test_rmse)
    print("Testing Mean Absolute Error (MAE):", test_mae)
    print("Testing R-squared (R^2) Score:", test_r2)

    # Plot loss versus epoch and validation loss versus epoch for training set
    plt.figure(figsize=(10, 5))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss vs. Epoch')
    plt.legend()
    plt.show()

    # Create a residual plot for training set
    residuals_train = y_train_lstm - y_train_pred_lstm
    plt.figure(figsize=(10, 5))
    plt.scatter(y_train_lstm, residuals_train, color='blue', alpha=0.6)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.xlabel('True Values')
    plt.ylabel('Residuals')
    plt.title(target)
    plt.show()

    # Plot actual vs. predicted values for training set
    plt.figure(figsize=(10, 8))
    plt.scatter(y_train_lstm, y_train_pred_lstm, label='Actual vs. Predicted', color='blue', alpha=0.7)
    plt.plot([y_train_lstm.min(), y_train_lstm.max()], [y_train_lstm.min(), y_train_lstm.max()], 'k--', lw=2, label='Ideal')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Actual vs. Predicted Values (Training Set)')
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.show()

    # Plot actual vs. predicted values with time for testing set
    test_index = dfs.index[-len(y_test_lstm):]
    plt.figure(figsize=(10, 8))
    plt.plot(test_index, y_test_lstm, label='Test Data', color='#1f76b4')
    plt.plot(test_index, y_test_pred_lstm, label='Predicted Test Data', color='red')
    plt.legend()
    #plt.xticks([])
    plt.title('Actual vs. Predicted Values over Time (Testing Set)')
    plt.ylabel(target)
    plt.xlabel('Date')
    plt.show()

      # Plot actual vs. predicted values with time for testing set
    plt.figure(figsize=(15, 5))
    train_index = data_mlvt.index[:split_index][-len(y_train_lstm):]
    test_index = data_mlvt.index[split_index:]
    plt.plot(data_mlvt.index, data_mlvt[target], label='Historical Data', color='gray')
    plt.plot(train_index, y_train_lstm, label='Train Data', color='blue')
    plt.plot(test_index, y_test_lstm, label='Test Data', color='#1f76b4')
    plt.plot(test_index, y_test_pred_lstm, label='Predicted Test Data', color='red')
    plt.plot(train_index, y_train_pred_lstm, label='Predicted Train Data', color='green', linestyle='dashed')
    plt.legend()
    plt.title(target)
    plt.ylabel(target)
    plt.xlabel('Date')
    plt.show()  

    return y_train_lstm, y_train_pred_lstm, y_test_lstm, y_test_pred_lstm

# %%
def create_sequences(data, target, lookback):
    X, y = [], []
    for i in range(len(data) - lookback):
        X.append(data[i:i + lookback, :-1])  # Features
        y.append(data[i + lookback - 1, -1])  # Target
    return np.array(X), np.array(y)

def lstm_mlvt_model2(target, data_mlvt, features, lookback, train_test_split=0.8):
    dfs = data_mlvt[['Date'] + features + [target]]
    dfs['Date'] = pd.to_datetime(dfs['Date'])
    dfs.set_index('Date', inplace=True)

    # Separate target and features
    target_data = dfs[[target]].values
    feature_data = dfs[features].values

    # Apply MinMax scaling with rounding
    scaler_features = MinMaxScaler(feature_range=(0, 1))
    scaler_target = MinMaxScaler(feature_range=(0, 1))

    feature_data_scaled = np.round(scaler_features.fit_transform(feature_data), 4)
    target_data_scaled = np.round(scaler_target.fit_transform(target_data), 4)

    data_scaled = np.hstack((feature_data_scaled, target_data_scaled))

    # Train-test split
    split_index = int(len(data_scaled) * train_test_split)
    train_data_scaled = data_scaled[:split_index]
    test_data_scaled = data_scaled[split_index:]

    X_train_lstm, y_train_lstm = create_sequences(train_data_scaled, target_data_scaled, lookback)
    X_test_lstm, y_test_lstm = create_sequences(test_data_scaled, target_data_scaled, lookback)

    model = Sequential()
    model.add(LSTM(units=64, activation='relu', input_shape=(lookback, len(features)), return_sequences=True))
    model.add(LSTM(units=32, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(X_train_lstm, y_train_lstm, epochs=100, batch_size=30, validation_split=0.2, verbose=1)

    y_train_pred_lstm = model.predict(X_train_lstm)
    y_test_pred_lstm = model.predict(X_test_lstm)

    y_train_pred_lstm = y_train_pred_lstm.reshape(-1)
    y_test_pred_lstm = y_test_pred_lstm.reshape(-1)

    # Inverse transform the predicted and target values back to the original scale
    y_train_pred_lstm = scaler_target.inverse_transform(y_train_pred_lstm.reshape(-1, 1)).flatten()
    y_train_lstm = scaler_target.inverse_transform(y_train_lstm.reshape(-1, 1)).flatten()

    y_test_pred_lstm = scaler_target.inverse_transform(y_test_pred_lstm.reshape(-1, 1)).flatten()
    y_test_lstm = scaler_target.inverse_transform(y_test_lstm.reshape(-1, 1)).flatten()

    # Calculate metrics for both training and testing sets
    train_mse = mean_squared_error(y_train_lstm, y_train_pred_lstm)
    train_rmse = np.sqrt(train_mse)
    train_mae = mean_absolute_error(y_train_lstm, y_train_pred_lstm)
    train_r2 = r2_score(y_train_lstm, y_train_pred_lstm)

    test_mse = mean_squared_error(y_test_lstm, y_test_pred_lstm)
    test_rmse = np.sqrt(test_mse)
    test_mae = mean_absolute_error(y_test_lstm, y_test_pred_lstm)
    test_r2 = r2_score(y_test_lstm, y_test_pred_lstm)

    # Print metrics for both training and testing sets
    print("Training Mean Squared Error (MSE):", train_mse)
    print("Training Root Mean Squared Error (RMSE):", train_rmse)
    print("Training Mean Absolute Error (MAE):", train_mae)
    print("Training R-squared (R^2) Score:", train_r2)

    print("Testing Mean Squared Error (MSE):", test_mse)
    print("Testing Root Mean Squared Error (RMSE):", test_rmse)
    print("Testing Mean Absolute Error (MAE):", test_mae)
    print("Testing R-squared (R^2) Score:", test_r2)

    # Plot loss versus epoch and validation loss versus epoch for training set
    plt.figure(figsize=(10, 5))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss vs. Epoch')
    plt.legend()
    plt.show()

    # Create a residual plot for training set
    residuals_train = y_train_lstm - y_train_pred_lstm
    plt.figure(figsize=(10, 5))
    plt.scatter(y_train_lstm, residuals_train, color='blue', alpha=0.6)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.xlabel('True Values')
    plt.ylabel('Residuals')
    plt.title(target)
    plt.show()

    # Plot actual vs. predicted values for training set
    plt.figure(figsize=(10, 8))
    plt.scatter(y_train_lstm, y_train_pred_lstm, label='Actual vs. Predicted (Train)', color='blue', alpha=0.7)
    plt.plot([y_train_lstm.min(), y_train_lstm.max()], [y_train_lstm.min(), y_train_lstm.max()], 'k--', lw=2, label='Ideal')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Actual vs. Predicted Values (Training Set)')
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.show()


    # Plot actual vs. predicted values with time for testing set
    #plt.figure(figsize=(15, 5))
    #plt.plot(data_mlvt.index, data_mlvt[target], label='Historical Data', color='gray')
    #test_index = dfs.index[-len(y_test_lstm):]
    #plt.figure(figsize=(10, 8))
    #plt.plot(test_index, y_test_lstm, label='Test Data', color='#1f76b4')
    #plt.plot(test_index, y_test_pred_lstm, label='Predicted Test Data', color='red')
    #plt.legend()
    #plt.xticks([])
    #plt.title('Actual vs. Predicted Values over Time (Testing Set)')
    #plt.ylabel(target)
    #plt.xlabel('Date')
    #plt.show()
    # Plot actual, train data, and predicted test data for LSTM
    
    plt.figure(figsize=(15, 5))
    plt.plot(data_mlvt.index, data_mlvt[target], label='Historical Data', color='gray')
    plt.plot(train_index[-len(y_train_lstm):], y_train_lstm, label='Train Data', color='blue')
    plt.plot(test_index[:len(y_test_lstm)], y_test_lstm, label='Test Data', color='#1f76b4')
    plt.plot(test_index[:len(y_test_pred_lstm)], y_test_pred_lstm, label='Predicted Test Data', color='red')
    plt.plot(train_index[-len(y_train_pred_lstm):], y_train_pred_lstm, label='Predicted Train Data', color='green', linestyle='dashed')
    plt.axvline(x= split_index, color='gray', linestyle='--', label='Train-Test Split')  # Vertical line at train-test split point
    plt.legend()
    plt.title(target)
    plt.ylabel(target)
    plt.xlabel('Date')
    plt.show()

    return y_train_lstm, y_train_pred_lstm, y_test_lstm, y_test_pred_lstm

# %%
def create_sequences(data, target, lookback):
    X, y = [], []
    for i in range(len(data) - lookback):
        X.append(data[i:i + lookback, :-1])  # Features
        y.append(data[i + lookback - 1, -1])  # Target
    return np.array(X), np.array(y)

def lstm_mlvt_model2(target, data_mlvt, features, lookback, train_test_split=0.8):
    dfs = data_mlvt[['Date'] + features + [target]]
    dfs['Date'] = pd.to_datetime(dfs['Date'])
    dfs.set_index('Date', inplace=True)

    # Separate target and features
    target_data = dfs[[target]].values
    feature_data = dfs[features].values

    # Apply MinMax scaling with rounding
    scaler_features = MinMaxScaler(feature_range=(0, 1))
    scaler_target = MinMaxScaler(feature_range=(0, 1))

    feature_data_scaled = np.round(scaler_features.fit_transform(feature_data), 4)
    target_data_scaled = np.round(scaler_target.fit_transform(target_data), 4)

    data_scaled = np.hstack((feature_data_scaled, target_data_scaled))

    # Train-test split
    split_index = int(len(data_scaled) * train_test_split)
    train_data_scaled = data_scaled[:split_index]
    test_data_scaled = data_scaled[split_index:]

    X_train_lstm, y_train_lstm = create_sequences(train_data_scaled, target_data_scaled, lookback)
    X_test_lstm, y_test_lstm = create_sequences(test_data_scaled, target_data_scaled, lookback)

#print('data_mlvt_shape, data_scaled_shape, X_lstm_shape, y_lstm_shape, X_lstm_shape[0]+X_lstm_shape[1]
#      =',data_mlvt.shape, data_scaled.shape, X_lstm.shape, y_lstm.shape, X_lstm.shape[0]+X_lstm.shape[1])

    print('mlvtshape, data_scaled_shape, X_train_lstm_shape, X_test_lstm_shape, y_train_lstm_shape, y_test_lstm_shape =',data_mlvt.shape, data_scaled.shape, X_train_lstm.shape, X_test_lstm.shape, y_train_lstm.shape, y_test_lstm.shape)

    es =EarlyStopping(mode='min', verbose=1, patience=20)

    model = Sequential()
    model.add(LSTM(units=64, activation='relu', input_shape=(lookback, len(features)), return_sequences=True))
    model.add(LSTM(units=32, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(X_train_lstm, y_train_lstm, epochs=100, batch_size=30, verbose=2, callbacks=es)#, validation_split=0.2, verbose=1)
    print(model.summary())


    print('0y_train_lstm =',y_train_lstm.shape)
    print('0y_test_lstm =',y_test_lstm.shape)
    print('0X_train_lstm =',X_train_lstm.shape)
    print('0X_test_lstm =',X_test_lstm.shape)
    

    y_train_pred_lstm = model.predict(X_train_lstm)
    y_test_pred_lstm = model.predict(X_test_lstm)

    


    print('1y_train_pred_lstm =',y_train_pred_lstm.shape)
    print('1y_train_lstm =',y_train_lstm.shape)
    print('1y_test_pred_lstm =',y_test_pred_lstm.shape)
    print('1y_test_lstm =',y_test_lstm.shape)


    y_train_pred_lstm = y_train_pred_lstm.flatten()#reshape(-1)
    y_test_pred_lstm = y_test_pred_lstm.flatten()#reshape(-1)

    # Inverse transform the predicted and target values back to the original scale
    y_train_pred_lstm = scaler_target.inverse_transform(y_train_pred_lstm.reshape(-1, 1)).flatten()
    y_train_lstm = scaler_target.inverse_transform(y_train_lstm.reshape(-1, 1)).flatten()

    y_test_pred_lstm = scaler_target.inverse_transform(y_test_pred_lstm.reshape(-1, 1)).flatten()
    y_test_lstm = scaler_target.inverse_transform(y_test_lstm.reshape(-1, 1)).flatten()

    print('2y_train_pred_lstm =',y_train_pred_lstm.shape)
    print('2y_train_lstm =',y_train_lstm.shape)
    print('2y_test_pred_lstm =',y_test_pred_lstm.shape)
    print('2y_test_lstm =',y_test_lstm.shape)



    # Calculate metrics for both training and testing sets
    train_mse = mean_squared_error(y_train_lstm, y_train_pred_lstm)
    train_rmse = np.sqrt(train_mse)
    train_mae = mean_absolute_error(y_train_lstm, y_train_pred_lstm)
    train_r2 = r2_score(y_train_lstm, y_train_pred_lstm)

    test_mse = mean_squared_error(y_test_lstm, y_test_pred_lstm)
    test_rmse = np.sqrt(test_mse)
    test_mae = mean_absolute_error(y_test_lstm, y_test_pred_lstm)
    test_r2 = r2_score(y_test_lstm, y_test_pred_lstm)

    # Print metrics for both training and testing sets
    print("Training Mean Squared Error (MSE):", train_mse)
    print("Training Root Mean Squared Error (RMSE):", train_rmse)
    print("Training Mean Absolute Error (MAE):", train_mae)
    print("Training R-squared (R^2) Score:", train_r2)

    print("Testing Mean Squared Error (MSE):", test_mse)
    print("Testing Root Mean Squared Error (RMSE):", test_rmse)
    print("Testing Mean Absolute Error (MAE):", test_mae)
    print("Testing R-squared (R^2) Score:", test_r2)

    # Plot loss versus epoch and validation loss versus epoch for training set
    plt.figure(figsize=(10, 5))
    plt.plot(history.history['loss'], label='Training Loss')
    #plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss vs. Epoch')
    plt.legend()
    plt.show()

    # Create a residual plot for training set
    residuals_train = y_train_lstm - y_train_pred_lstm
    plt.figure(figsize=(10, 5))
    plt.scatter(y_train_lstm, residuals_train, color='blue', alpha=0.6)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.xlabel('True Values')
    plt.ylabel('Residuals')
    plt.title(target)
    plt.show()

    # Plot actual vs. predicted values for training set
    plt.figure(figsize=(10, 8))
    plt.scatter(y_train_lstm, y_train_pred_lstm, label='Actual vs. Predicted (Train)', color='blue', alpha=0.7)
    plt.plot([y_train_lstm.min(), y_train_lstm.max()], [y_train_lstm.min(), y_train_lstm.max()], 'k--', lw=2, label='Ideal')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Actual vs. Predicted Values (Training Set)')
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.show()

    # Get the train and test data indices
    split_index = int(len(data_mlvt) * 0.8)
    train_start_index = lookback
    train_end_index = split_index
    test_start_index = split_index + lookback  # Ensure test data starts after train data
    test_end_index = len(data_mlvt)

    # Get the corresponding time indices for train and test data
    train_time_index = data_mlvt.index[train_start_index:train_end_index]
    test_time_index = data_mlvt.index[test_start_index:test_end_index]

    # Plot actual vs. predicted values with time for testing set
    plt.figure(figsize=(10, 8))
    plt.plot(data_mlvt.index, data_mlvt[target], label='Historical Data', color='gray')
    plt.plot(test_time_index, y_test_lstm, label='Test Data', color='#1f76b4')
    plt.plot(test_time_index, y_test_pred_lstm, label='Predicted Test Data', color='red')
    plt.axvline(x=split_index, color='red', linestyle='--', label='Train-Test Split')
    plt.legend()
    plt.title('Actual vs. Predicted Values over Time (Testing Set)')
    plt.ylabel(target)
    plt.xlabel('Date')
    plt.show()

    # Plot actual, train data, and predicted test data for LSTM
    plt.figure(figsize=(15, 5))
    plt.plot(data_mlvt.index, data_mlvt[target], label='Historical Data', color='gray')
    plt.plot(train_time_index, y_train_lstm, label='Train Data', color='blue')
    plt.plot(test_time_index, y_test_lstm, label='Test Data', color='#1f76b4')
    plt.plot(test_time_index, y_test_pred_lstm, label='Predicted Test Data', color='red')
    plt.plot(train_time_index, y_train_pred_lstm, label='Predicted Train Data', color='green', linestyle='dashed')
    plt.axvline(x=split_index, color='red', linestyle='--', label='Train-Test Split')
    plt.legend()
    plt.title(target)
    plt.ylabel(target)
    plt.xlabel('Date')
    plt.show()
    print(model.summary())
    #df_pred_test_multi = create_pred_df_multi(y_test_lstm, y_test_pred_lstm)
    #df_pred_train_multi = create_pred_df_multi(y_train_lstm, y_train_pred_lstm)
    # Simple LSTM result
    #plt.figure(figsize=(12,6))
    # sns.lineplot(data=df_pred_train[-500:])
    #sns.lineplot(data=df_pred_train_multi[-500:])
    #plt.legend()    

    return y_train_lstm, y_train_pred_lstm, y_test_lstm, y_test_pred_lstm

# %%
columns_mlvt= ['Date','Mean_air_temperature_de_c', 'Mean_precipitation_de_mm', 'Solar_gwh'] #'Total_other_renewable_gwh'
#target = 'Total_energy_generation_gwh'
data_mlvt = data_df[columns_mlvt].copy()
#data_mlvt.head()

data = data_df.copy()
#target = 'Total_energy_generation_gwh'
features = ['Mean_air_temperature_de_c', 'Mean_precipitation_de_mm']
target = 'Solar_gwh'
lookback = 12
train_test_split=0.8
#features =  ['Mean_sunshine_duration_de_minute']#['Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute', 'Mean_precipitation_de_mm']
#lstm_mlvt_model_tst_trn(target, data_mlvt, features, lookback)

#y_train, y_train_pred, y_test, y_test_pred = 
results = lstm_mlvt_model2(target, data_mlvt, features, lookback, train_test_split)


#df_pred_test_multi = create_pred_df_multi(y_test_lstm, y_test_pred_lstm[target].values)
#df_pred_train_multi = create_pred_df_multi(y_train_lstm, y_train_pred_lstm[target].values)
# Out:
# mlvtshape, data_scaled_shape, X_train_lstm_shape, X_test_lstm_shape, y_train_lstm_shape, y_test_lstm_shape = (102, 4) (102, 3) (69, 12, 2) (9, 12, 2) (69,) (9,)
# Epoch 1/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 1s - loss: 0.1516 - 1s/epoch - 359ms/step
# Epoch 2/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.1228 - 52ms/epoch - 17ms/step
# Epoch 3/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0982 - 43ms/epoch - 14ms/step
# Epoch 4/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0769 - 20ms/epoch - 7ms/step
# Epoch 5/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0652 - 21ms/epoch - 7ms/step
# Epoch 6/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0740 - 15ms/epoch - 5ms/step
# Epoch 7/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0709 - 14ms/epoch - 5ms/step
# Epoch 8/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0657 - 14ms/epoch - 5ms/step
# Epoch 9/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0643 - 16ms/epoch - 5ms/step
# Epoch 10/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0654 - 14ms/epoch - 5ms/step
# Epoch 11/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0660 - 14ms/epoch - 5ms/step
# Epoch 12/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0650 - 14ms/epoch - 5ms/step
# Epoch 13/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0630 - 14ms/epoch - 5ms/step
# Epoch 14/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0615 - 15ms/epoch - 5ms/step
# Epoch 15/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0608 - 17ms/epoch - 6ms/step
# Epoch 16/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0593 - 16ms/epoch - 5ms/step
# Epoch 17/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0584 - 21ms/epoch - 7ms/step
# Epoch 18/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0573 - 17ms/epoch - 6ms/step
# Epoch 19/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0561 - 17ms/epoch - 6ms/step
# Epoch 20/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0546 - 14ms/epoch - 5ms/step
# Epoch 21/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0528 - 14ms/epoch - 5ms/step
# Epoch 22/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0507 - 15ms/epoch - 5ms/step
# Epoch 23/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0480 - 14ms/epoch - 5ms/step
# Epoch 24/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0450 - 13ms/epoch - 4ms/step
# Epoch 25/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0418 - 14ms/epoch - 5ms/step
# Epoch 26/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0369 - 13ms/epoch - 4ms/step
# Epoch 27/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0323 - 13ms/epoch - 4ms/step
# Epoch 28/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0274 - 13ms/epoch - 4ms/step
# Epoch 29/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0219 - 14ms/epoch - 5ms/step
# Epoch 30/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0176 - 13ms/epoch - 4ms/step
# Epoch 31/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0169 - 35ms/epoch - 12ms/step
# Epoch 32/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0131 - 30ms/epoch - 10ms/step
# Epoch 33/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0110 - 22ms/epoch - 7ms/step
# Epoch 34/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0103 - 15ms/epoch - 5ms/step
# Epoch 35/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0092 - 14ms/epoch - 5ms/step
# Epoch 36/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0124 - 16ms/epoch - 5ms/step
# Epoch 37/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0113 - 16ms/epoch - 5ms/step
# Epoch 38/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0137 - 16ms/epoch - 5ms/step
# Epoch 39/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0101 - 16ms/epoch - 5ms/step
# Epoch 40/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0091 - 16ms/epoch - 5ms/step
# Epoch 41/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0104 - 16ms/epoch - 5ms/step
# Epoch 42/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0078 - 16ms/epoch - 5ms/step
# Epoch 43/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0102 - 16ms/epoch - 5ms/step
# Epoch 44/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0081 - 16ms/epoch - 5ms/step
# Epoch 45/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0078 - 16ms/epoch - 5ms/step
# Epoch 46/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0080 - 16ms/epoch - 5ms/step
# Epoch 47/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0078 - 16ms/epoch - 5ms/step
# Epoch 48/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0082 - 16ms/epoch - 5ms/step
# Epoch 49/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0076 - 16ms/epoch - 5ms/step
# Epoch 50/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0074 - 16ms/epoch - 5ms/step
# Epoch 51/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0082 - 16ms/epoch - 5ms/step
# Epoch 52/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0075 - 15ms/epoch - 5ms/step
# Epoch 53/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0077 - 15ms/epoch - 5ms/step
# Epoch 54/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0091 - 15ms/epoch - 5ms/step
# Epoch 55/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0088 - 15ms/epoch - 5ms/step
# Epoch 56/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0084 - 16ms/epoch - 5ms/step
# Epoch 57/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0074 - 15ms/epoch - 5ms/step
# Epoch 58/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0076 - 15ms/epoch - 5ms/step
# Epoch 59/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0076 - 15ms/epoch - 5ms/step
# Epoch 60/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0069 - 15ms/epoch - 5ms/step
# Epoch 61/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0078 - 14ms/epoch - 5ms/step
# Epoch 62/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0075 - 15ms/epoch - 5ms/step
# Epoch 63/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0069 - 16ms/epoch - 5ms/step
# Epoch 64/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0092 - 15ms/epoch - 5ms/step
# Epoch 65/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0088 - 15ms/epoch - 5ms/step
# Epoch 66/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0063 - 15ms/epoch - 5ms/step
# Epoch 67/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0095 - 15ms/epoch - 5ms/step
# Epoch 68/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0067 - 15ms/epoch - 5ms/step
# Epoch 69/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0065 - 16ms/epoch - 5ms/step
# Epoch 70/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0071 - 15ms/epoch - 5ms/step
# Epoch 71/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0069 - 15ms/epoch - 5ms/step
# Epoch 72/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0062 - 15ms/epoch - 5ms/step
# Epoch 73/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0069 - 15ms/epoch - 5ms/step
# Epoch 74/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0061 - 15ms/epoch - 5ms/step
# Epoch 75/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0065 - 15ms/epoch - 5ms/step
# Epoch 76/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0061 - 15ms/epoch - 5ms/step
# Epoch 77/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0059 - 18ms/epoch - 6ms/step
# Epoch 78/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0060 - 14ms/epoch - 5ms/step
# Epoch 79/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0057 - 14ms/epoch - 5ms/step
# Epoch 80/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0057 - 14ms/epoch - 5ms/step
# Epoch 81/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0064 - 15ms/epoch - 5ms/step
# Epoch 82/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0054 - 15ms/epoch - 5ms/step
# Epoch 83/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0063 - 16ms/epoch - 5ms/step
# Epoch 84/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0065 - 16ms/epoch - 5ms/step
# Epoch 85/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0054 - 15ms/epoch - 5ms/step
# Epoch 86/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0073 - 15ms/epoch - 5ms/step
# Epoch 87/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0063 - 16ms/epoch - 5ms/step
# Epoch 88/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0059 - 16ms/epoch - 5ms/step
# Epoch 89/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0062 - 15ms/epoch - 5ms/step
# Epoch 90/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0053 - 15ms/epoch - 5ms/step
# Epoch 91/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0061 - 15ms/epoch - 5ms/step
# Epoch 92/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0054 - 15ms/epoch - 5ms/step
# Epoch 93/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0056 - 15ms/epoch - 5ms/step
# Epoch 94/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0056 - 15ms/epoch - 5ms/step
# Epoch 95/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0054 - 15ms/epoch - 5ms/step
# Epoch 96/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0055 - 14ms/epoch - 5ms/step
# Epoch 97/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0048 - 15ms/epoch - 5ms/step
# Epoch 98/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0059 - 15ms/epoch - 5ms/step
# Epoch 99/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0051 - 15ms/epoch - 5ms/step
# Epoch 100/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 3/3 - 0s - loss: 0.0051 - 15ms/epoch - 5ms/step
# Model: "sequential_134"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_268 (LSTM)             (None, 12, 64)            17152
#
#  lstm_269 (LSTM)             (None, 32)                12416
#
#  dense_135 (Dense)           (None, 1)                 33
#
# =================================================================
# Total params: 29601 (115.63 KB)
# Trainable params: 29601 (115.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 0y_train_lstm = (69,)
# 0y_test_lstm = (9,)
# 0X_train_lstm = (69, 12, 2)
# 0X_test_lstm = (9, 12, 2)
# 3/3 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1y_train_pred_lstm = (69, 1)
# 1y_train_lstm = (69,)
# 1y_test_pred_lstm = (9, 1)
# 1y_test_lstm = (9,)
# 2y_train_pred_lstm = (69,)
# 2y_train_lstm = (69,)
# 2y_test_pred_lstm = (9,)
# 2y_test_lstm = (9,)
# Training Mean Squared Error (MSE): 384408.0300500581
# Training Root Mean Squared Error (RMSE): 620.0064758130015
# Training Mean Absolute Error (MAE): 486.8612325619112
# Training R-squared (R^2) Score: 0.9041034437108033
# Testing Mean Squared Error (MSE): 1114464.1367523624
# Testing Root Mean Squared Error (RMSE): 1055.681835001608
# Testing Mean Absolute Error (MAE): 770.229315763368
# Testing R-squared (R^2) Score: 0.7712428037313692
# Model: "sequential_134"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_268 (LSTM)             (None, 12, 64)            17152
#
#  lstm_269 (LSTM)             (None, 32)                12416
#
#  dense_135 (Dense)           (None, 1)                 33
#
# =================================================================
# Total params: 29601 (115.63 KB)
# Trainable params: 29601 (115.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Function to create the LSTM model
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(50, input_shape=input_shape))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    return model

# Function to create the training and testing datasets
def create_dataset(data, lookback, target):
    X, y = [], []
    for i in range(len(data) - lookback):
        X.append(data[i:(i + lookback)])
        y.append(data[i + lookback][target])
    return np.array(X), np.array(y)

def lstm_mlvt_model2(target, data_mlvt, features, lookback, train_test_split):
    # Extract the target variable
    data_mlvt = data_mlvt[['Date'] + features + [target]].copy()

    # Normalize the data
    scaler = MinMaxScaler()
    data_mlvt[features + [target]] = scaler.fit_transform(data_mlvt[features + [target]])

    # Create train and test datasets
    split_index = int(len(data_mlvt) * train_test_split)
    train_data = data_mlvt.iloc[:split_index].copy()
    test_data = data_mlvt.iloc[split_index:].copy()

    # Create the training and testing datasets
    X_train_lstm, y_train_lstm = create_dataset(train_data.values, lookback, target)
    X_test_lstm, y_test_lstm = create_dataset(test_data.values, lookback, target)

    # Reshape the training and testing data for LSTM
    X_train_lstm = X_train_lstm.reshape(X_train_lstm.shape[0], X_train_lstm.shape[1], len(features))
    X_test_lstm = X_test_lstm.reshape(X_test_lstm.shape[0], X_test_lstm.shape[1], len(features))

    print('0y_train_pred_lstm =',y_train_pred_lstm.shape)
    print('0y_train_lstm =',y_train_lstm.shape)
    print('0y_test_pred_lstm =',y_test_pred_lstm.shape)
    print('0y_test_lstm =',y_test_lstm.shape)

    # Create and train the LSTM model
    model = create_lstm_model(input_shape=(X_train_lstm.shape[1], X_train_lstm.shape[2]))
    history = model.fit(X_train_lstm, y_train_lstm, epochs=100, batch_size=1, verbose=1)


    print('1y_train_pred_lstm =',y_train_pred_lstm.shape)
    print('1y_train_lstm =',y_train_lstm.shape)
    print('1y_test_pred_lstm =',y_test_pred_lstm.shape)
    print('1y_test_lstm =',y_test_lstm.shape)

    # Make predictions on training and testing data
    y_train_pred_lstm = model.predict(X_train_lstm)
    y_test_pred_lstm = model.predict(X_test_lstm)

    # Reshape the predictions to match the original format
    y_train_pred_lstm = y_train_pred_lstm.flatten()
    y_test_pred_lstm = y_test_pred_lstm.flatten()

    print('2y_train_pred_lstm =',y_train_pred_lstm.shape)
    print('2y_train_lstm =',y_train_lstm.shape)
    print('2y_test_pred_lstm =',y_test_pred_lstm.shape)
    print('2y_test_lstm =',y_test_lstm.shape)


    # Create index for plotting
    train_time_index = data_mlvt['Date'].iloc[lookback:split_index]
    test_time_index = data_mlvt['Date'].iloc[split_index + lookback:]

    # Plot actual vs. predicted values with time for training and testing set
    plt.figure(figsize=(15, 5))
    plt.plot(data_mlvt['Date'], data_mlvt[target], label='Historical Data', color='gray')
    plt.plot(train_time_index, y_train_lstm, label='Train Data', color='blue')
    plt.plot(test_time_index, y_test_lstm, label='Test Data', color='#1f76b4')
    plt.plot(test_time_index, y_test_pred_lstm, label='Predicted Test Data', color='red')
    plt.plot(train_time_index, y_train_pred_lstm, label='Predicted Train Data', color='green', linestyle='dashed')
    plt.axvline(x=data_mlvt['Date'].iloc[split_index], color='red', linestyle='--', label='Train-Test Split')
    plt.legend()
    plt.title('Actual vs. Predicted Values over Time')
    plt.xlabel('Date')
    plt.ylabel(target)
    plt.show()
    print(model.summary())

# %%
columns_mlvt= ['Date','Mean_air_temperature_de_c', 'Mean_precipitation_de_mm', 'Solar_gwh'] #'Total_other_renewable_gwh'
#target = 'Total_energy_generation_gwh'
data_mlvt = data_df[columns_mlvt].copy()
#data_mlvt.head()

data = data_df.copy()
#target = 'Total_energy_generation_gwh'
features = ['Mean_air_temperature_de_c', 'Mean_precipitation_de_mm']
target = 'Solar_gwh'
lookback = 12
train_test_split=0.8
#features =  ['Mean_sunshine_duration_de_minute']#['Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute', 'Mean_precipitation_de_mm']
#lstm_mlvt_model_tst_trn(target, data_mlvt, features, lookback)

#y_train, y_train_pred, y_test, y_test_pred = 
results = lstm_mlvt_model2(target, data_mlvt, features, lookback, train_test_split)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1159], line 16
#      11 train_test_split=0.8
#      12 #features =  ['Mean_sunshine_duration_de_minute']#['Mean_air_temperature_de_c', 'Mean_sunshine_duration_de_minute', 'Mean_precipitation_de_mm']
#      13 #lstm_mlvt_model_tst_trn(target, data_mlvt, features, lookback)
#      14
#      15 #y_train, y_train_pred, y_test, y_test_pred =
# ---> 16 results = lstm_mlvt_model2(target, data_mlvt, features, lookback, train_test_split)
#
# Cell In[1158], line 31, in lstm_mlvt_model2(target, data_mlvt, features, lookback, train_test_split)
#      28 test_data = data_mlvt.iloc[split_index:].copy()
#      30 # Create the training and testing datasets
# ---> 31 X_train_lstm, y_train_lstm = create_dataset(train_data.values, lookback, target)
#      32 X_test_lstm, y_test_lstm = create_dataset(test_data.values, lookback, target)
#      34 # Reshape the training and testing data for LSTM
#
# Cell In[1158], line 14, in create_dataset(data, lookback, target)
#      12 for i in range(len(data) - lookback):
#      13     X.append(data[i:(i + lookback)])
# ---> 14     y.append(data[i + lookback][target])
#      15 return np.array(X), np.array(y)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %% [markdown]
# ## Format Data & Feature Engineering
#
# The dataset includes a timestamp. It might be interesting to have a look at additional features like for example `month`, `day`, `day of the year`, and `ho

# %%
#data_df_mwh.columns

# %% [markdown]
# #### Unit conversion from 'mwh' to 'gwh'

# %%
data_df_gwh = data_df_mwh.copy()

# %%
#data_df_mwh['Marine_mwh']
data_df_gwh.columns
# Out:
# Index(['Area', 'Mtu', 'Biomass_mwh', 'Fossil_brown_coal_mwh',
#        'Fossil_coal_derived_gas_mwh', 'Fossil_gas_mwh', 'Fossil_hard_coal_mwh',
#        'Fossil_oil_mwh', 'Fossil_oil_shale_mwh', 'Fossil_peat_mwh',
#        'Geothermal_mwh', 'Hydro_pumped_storage_aggregated_mwh',
#        'Hydro_pumped_storage_consumption_mwh',
#        'Hydro_run_of_river_and_poundage_mwh', 'Hydro_water_reservoir_mwh',
#        'Marine_mwh', 'Nuclear_mwh', 'Other_mwh', 'Other_renewable_mwh',
#        'Solar_mwh', 'Waste_mwh', 'Wind_offshore_mwh', 'Wind_onshore_mwh',
#        'Date', 'Hour', 'Total_energy_generation_mwh', 'Solar/total_energy',
#        'Diff_total_energy_and_solar_mwh', 'Total_other_renewable_mwh'],
#       dtype='object')

# %%
# Here we convert  unit from mwh to gwh 
for col in ['Biomass_mwh', 'Fossil_brown_coal_mwh',
       'Fossil_coal_derived_gas_mwh', 'Fossil_gas_mwh', 'Fossil_hard_coal_mwh',
       'Fossil_oil_mwh', 'Fossil_oil_shale_mwh', 'Fossil_peat_mwh',
       'Geothermal_mwh', 'Hydro_pumped_storage_aggregated_mwh',
       'Hydro_pumped_storage_consumption_mwh',
       'Hydro_run_of_river_and_poundage_mwh', 'Hydro_water_reservoir_mwh',
       'Marine_mwh', 'Nuclear_mwh', 'Other_mwh', 'Other_renewable_mwh',
       'Solar_mwh', 'Waste_mwh', 'Wind_offshore_mwh', 'Wind_onshore_mwh','Total_energy_generation_mwh', 'Diff_total_energy_and_solar_mwh', 'Total_other_renewable_mwh']:
       data_df_gwh[col] =  data_df_gwh[col]/1000.

# %%
# Here we rename columns from *_mwh to *_gwh
for col in data_df_gwh.columns:
       data_df_gwh.rename(columns={col:col.replace('mwh','gwh')},inplace=True)

# %%
#ycol_all_renw = ['Total_energy_generation_gwh', 'Solar_gwh', 'Solar/energy_total','Diff_total_energy_and_solar_gwh',
#             'Wind_onshore_gwh','Wind_offshore_gwh','Waste_gwh','Solar_gwh','Other_renewable_gwh',  'Total_other_renewable_gwh'
#             'Marine_gwh','Hydro_run_of_river_and_poundage_gwh','Hydro_water_reservoir_gwh','Geothermal_gwh']

#ycol_renw = ['Wind_onshore_gwh','Wind_offshore_gwh','Waste_gwh','Other_renewable_gwh',  'Total_other_renewable_gwh'
#             'Marine_gwh','Hydro_run_of_river_and_poundage_gwh','Hydro_water_reservoir_gwh','Geothermal_gwh']

# %%
data_df_gwh.head()
# Out:
#            Area                   Mtu  Biomass_gwh  Fossil_brown_coal_gwh  \
# 0  Germany (DE)  20150101 00:00-01:00      3.99750               15.68725
# 1  Germany (DE)  20150101 01:00-02:00      3.95650               15.32175
# 2  Germany (DE)  20150101 02:00-03:00      3.99175               14.81750
# 3  Germany (DE)  20150101 03:00-04:00      4.00975               14.07500
# 4  Germany (DE)  20150101 04:00-05:00      4.00600               14.11500
#
#    Fossil_coal_derived_gas_gwh  Fossil_gas_gwh  Fossil_hard_coal_gwh  \
# 0                          0.0         1.22625               3.21975
# 1                          0.0         0.87075               2.35125
# 2                          0.0         0.80950               2.22700
# 3                          0.0         0.82100               2.33975
# 4                          0.0         0.83125               2.46150
#
#    Fossil_oil_gwh  Fossil_oil_shale_gwh  Fossil_peat_gwh  ...  Solar_gwh  \
# 0         0.17650                   0.0              0.0  ...        0.0
# 1         0.17450                   0.0              0.0  ...        0.0
# 2         0.17275                   0.0              0.0  ...        0.0
# 3         0.17325                   0.0              0.0  ...        0.0
# 4         0.17425                   0.0              0.0  ...        0.0
#
#    Waste_gwh  Wind_offshore_gwh  Wind_onshore_gwh      Date  Hour  \
# 0    0.29825            0.52100           8.84975  20150101     0
# 1    0.29500            0.52075           9.04650  20150101     1
# 2    0.28825            0.51900           9.19600  20150101     2
# 3    0.30350            0.52250           9.14675  20150101     3
# 4    0.30300            0.52425           9.20400  20150101     4
#
#    Total_energy_generation_gwh  Solar/total_energy  \
# 0                     51.45925                 0.0
# 1                     49.98825                 0.0
# 2                     49.26525                 0.0
# 3                     48.53800                 0.0
# 4                     48.63000                 0.0
#
#    Diff_total_energy_and_solar_gwh  Total_other_renewable_gwh
# 0                         51.45925                    9.66900
# 1                         49.98825                    9.86225
# 2                         49.26525                   10.00325
# 3                         48.53800                    9.97275
# 4                         48.63000                   10.03125
#
# [5 rows x 29 columns]

# %% [markdown]
# #### 'data_df' set the unit of final processing data

# %%
data_df= data_df_gwh.copy()

# %%
data_df.head()
# Out:
#            Area                   Mtu  Biomass_gwh  Fossil_brown_coal_gwh  \
# 0  Germany (DE)  20150101 00:00-01:00      3.99750               15.68725
# 1  Germany (DE)  20150101 01:00-02:00      3.95650               15.32175
# 2  Germany (DE)  20150101 02:00-03:00      3.99175               14.81750
# 3  Germany (DE)  20150101 03:00-04:00      4.00975               14.07500
# 4  Germany (DE)  20150101 04:00-05:00      4.00600               14.11500
#
#    Fossil_coal_derived_gas_gwh  Fossil_gas_gwh  Fossil_hard_coal_gwh  \
# 0                          0.0         1.22625               3.21975
# 1                          0.0         0.87075               2.35125
# 2                          0.0         0.80950               2.22700
# 3                          0.0         0.82100               2.33975
# 4                          0.0         0.83125               2.46150
#
#    Fossil_oil_gwh  Fossil_oil_shale_gwh  Fossil_peat_gwh  ...  Solar_gwh  \
# 0         0.17650                   0.0              0.0  ...        0.0
# 1         0.17450                   0.0              0.0  ...        0.0
# 2         0.17275                   0.0              0.0  ...        0.0
# 3         0.17325                   0.0              0.0  ...        0.0
# 4         0.17425                   0.0              0.0  ...        0.0
#
#    Waste_gwh  Wind_offshore_gwh  Wind_onshore_gwh      Date  Hour  \
# 0    0.29825            0.52100           8.84975  20150101     0
# 1    0.29500            0.52075           9.04650  20150101     1
# 2    0.28825            0.51900           9.19600  20150101     2
# 3    0.30350            0.52250           9.14675  20150101     3
# 4    0.30300            0.52425           9.20400  20150101     4
#
#    Total_energy_generation_gwh  Solar/total_energy  \
# 0                     51.45925                 0.0
# 1                     49.98825                 0.0
# 2                     49.26525                 0.0
# 3                     48.53800                 0.0
# 4                     48.63000                 0.0
#
#    Diff_total_energy_and_solar_gwh  Total_other_renewable_gwh
# 0                         51.45925                    9.66900
# 1                         49.98825                    9.86225
# 2                         49.26525                   10.00325
# 3                         48.53800                    9.97275
# 4                         48.63000                   10.03125
#
# [5 rows x 29 columns]

# %%
data_df['Date'] = pd.to_datetime(data_df['Date'], format='%Y%m%d')
# Extract year, month and date from the datetime object
data_df['Year'] = data_df['Date'].dt.year
data_df['Month'] = data_df['Date'].dt.month
data_df['Day'] = data_df['Date'].dt.day
data_df['Dayofyear'] = data_df['Date'].dt.dayofyear
data_df.head()
# Out:
#            Area                   Mtu  Biomass_gwh  Fossil_brown_coal_gwh  \
# 0  Germany (DE)  20150101 00:00-01:00      3.99750               15.68725
# 1  Germany (DE)  20150101 01:00-02:00      3.95650               15.32175
# 2  Germany (DE)  20150101 02:00-03:00      3.99175               14.81750
# 3  Germany (DE)  20150101 03:00-04:00      4.00975               14.07500
# 4  Germany (DE)  20150101 04:00-05:00      4.00600               14.11500
#
#    Fossil_coal_derived_gas_gwh  Fossil_gas_gwh  Fossil_hard_coal_gwh  \
# 0                          0.0         1.22625               3.21975
# 1                          0.0         0.87075               2.35125
# 2                          0.0         0.80950               2.22700
# 3                          0.0         0.82100               2.33975
# 4                          0.0         0.83125               2.46150
#
#    Fossil_oil_gwh  Fossil_oil_shale_gwh  Fossil_peat_gwh  ...       Date  \
# 0         0.17650                   0.0              0.0  ... 2015-01-01
# 1         0.17450                   0.0              0.0  ... 2015-01-01
# 2         0.17275                   0.0              0.0  ... 2015-01-01
# 3         0.17325                   0.0              0.0  ... 2015-01-01
# 4         0.17425                   0.0              0.0  ... 2015-01-01
#
#    Hour  Total_energy_generation_gwh  Solar/total_energy  \
# 0     0                     51.45925                 0.0
# 1     1                     49.98825                 0.0
# 2     2                     49.26525                 0.0
# 3     3                     48.53800                 0.0
# 4     4                     48.63000                 0.0
#
#    Diff_total_energy_and_solar_gwh  Total_other_renewable_gwh  Year  Month  \
# 0                         51.45925                    9.66900  2015      1
# 1                         49.98825                    9.86225  2015      1
# 2                         49.26525                   10.00325  2015      1
# 3                         48.53800                    9.97275  2015      1
# 4                         48.63000                   10.03125  2015      1
#
#    Day  Dayofyear
# 0    1          1
# 1    1          1
# 2    1          1
# 3    1          1
# 4    1          1
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Visualize the Data
#
# Let us start by plotting the temperature data over time. We can either use the hourly development or aggregate the feature by day to get a less dense plot.

# %%
#data_df.isnull().sum()
#data_df = data_df.dropna()

# %% [markdown]
# - The target is fixed here. We can run the cell for any desirable y-axis data

# %%
#### Potential targets  (It corresponds to the rename column names.)
#title_main = 'Solar_gw' # General title of plots files

main_0  = 'Total_energy_generation_gwh' # This is only for energy
title_main = main_0.replace('_', ' ').replace('gwh', 'in GWh')# This is only for energy

#main_0  = 'Solar_gwh' # for all other columns
#title_main = main_0.replace('_', ' ').replace('gwh', 'energy in GWh')# for all other columns
print(title_main)

#### In units of mwh
#target = 'Total_energy_generation_mwh'
#target ='Solar_mwh'

#set  the ylabel
#ylable_0  = target.replace('_mwh', '(mwh)')
#ylable_target  = ylable_0.replace('_', ' ')
#print(ylable_target)


#### In units of gwh
target = 'Total_energy_generation_gwh'
#target ='Solar_gwh'
 

# here we set the ylabel
ylable_0  = target.replace('_gwh', '(GWh)')
ylable_target  = ylable_0.replace('_', ' ')
print(ylable_target)
# Out:
# Total energy generation in GWh
# Total energy generation(GWh)

# %% [markdown]
# ### Here we set the function for line plot

# %%
#average_lineplot_no_group(df=data_df, y= target, x="Date", time='Year')

# %%
# Aggregate Energy_mwh or Solar_mwh by day
daily_data_df = data_df \
    .groupby(['Date', 'Year', 'Month', 'Day', 'Dayofyear', 'Hour'], as_index=False)\
    .agg({target: np.sum}) \
    .set_index('Date')

# %%
# Plot yearly seasonality
fig, ax = plt.subplots() 

pd.pivot_table(data=daily_data_df[['Year', 'Dayofyear', target]], index='Dayofyear', columns='Year') \
    [target] \
    .plot(cmap='viridis', alpha=0.5, ax=ax)

ax.legend(title='Year', loc='center left', bbox_to_anchor=(1, 0.5))
ax.set(title= title_main +' '+'-'+' ' + ' ' +'Yearly(Dayofyear)', ylabel=ylable_target);
#fig.savefig("visualisations/total_energy_generation_mwh.png",dpi=300)

# %%
# We would like to check the average renewable energy  targets by years
#ycol_aggr = ['Total_energy_generation_gwh', 'Solar_gwh', 'Solar/total_energy','Diff_total_energy_and_solar_gwh',
#             'Total_other_renewable_gwh', 'Other_renewable_gwh', 'Wind_onshore_gwh','Wind_offshore_gwh','Waste_gwh','Solar_gwh', 
#             'Marine_gwh','Hydro_run_of_river_and_poundage_gwh','Hydro_water_reservoir_gwh','Geothermal_gwh']
#for col in ycol_aggr:
#    average_lineplot(df=data_df, y=col, x='Date', time='Dayofyear', group='Year')

# %%
def combine_date_and_time(df, date_column='Date', time_column='Hour', target_column=target):
    # Convert 'Date' column to datetime format
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Combine 'Date' and 'Hour' columns to create the 'Datetime' column
    df['Datetime'] = df.apply(lambda row: row[date_column] + pd.Timedelta(hours=row[time_column]), axis=1)
    
    # Select the desired columns for the final DataFrame
    df_result  = df[['Datetime', target_column]]
    
    return df_result
    #df_dt.head()

# %%
# Rolling mean
# window =
#df_dt[target]=data_df[target].rolling(window=365).mean() 
#df_dt = df_dt.dropna() #df_dt = df_dt.dropna(how='all')#(axis=0)
#df_dt = df_dt.dropna(axis=0)
# Reset index after drop
#df_dt=df_dt.dropna().reset_index(drop=True)
#df_dt.head()

# %%
#df_dt.loc[(df_dt.index > '2023-01-01') & (df_dt.index < '2023-12-01') ].plot(figsize=(15,5), ylabel=ylable_target, title= 'Data of last year', label = '2023 data')
#ax.legend(['2023 data'])
#plt.show()

# %%
def create_features(df):
    """
    create time series features based on time series index 
    """
    df['Hour'] = df.index.hour
    df['Year'] = df.index.year
    df['Month'] = df.index.month
   # df['Week'] = df.index.week
    df['Day'] = df.index.day
    #df['Dayofyear'] = df.index.dayofyear
    return df
#df_dt = create_features(df_dt)
#df_dt.head()

# %%
dfs = data_df[['Date', target]]

# %%
sns.distplot(dfs[target])
plt.title("Energy Distribution")
#sns.distplot(dfs['Solar_gwh'])
#plt.title("Solae Energy Distribution")
# Out:
# /var/folders/75/2hrhpj_x0q94k87nqmpdwckm0000gn/T/ipykernel_81468/1283765561.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfs[target])
# Text(0.5, 1.0, 'Energy Distribution')

# %%
data_df.columns
# Out:
# Index(['Area', 'Mtu', 'Biomass_gwh', 'Fossil_brown_coal_gwh',
#        'Fossil_coal_derived_gas_gwh', 'Fossil_gas_gwh', 'Fossil_hard_coal_gwh',
#        'Fossil_oil_gwh', 'Fossil_oil_shale_gwh', 'Fossil_peat_gwh',
#        'Geothermal_gwh', 'Hydro_pumped_storage_aggregated_gwh',
#        'Hydro_pumped_storage_consumption_gwh',
#        'Hydro_run_of_river_and_poundage_gwh', 'Hydro_water_reservoir_gwh',
#        'Marine_gwh', 'Nuclear_gwh', 'Other_gwh', 'Other_renewable_gwh',
#        'Solar_gwh', 'Waste_gwh', 'Wind_offshore_gwh', 'Wind_onshore_gwh',
#        'Date', 'Hour', 'Total_energy_generation_gwh', 'Solar/total_energy',
#        'Diff_total_energy_and_solar_gwh', 'Total_other_renewable_gwh', 'Year',
#        'Month', 'Day', 'Dayofyear'],
#       dtype='object')

# %%
#average_lineplot_no_group_ren(df=data_df, y='Total_other_renewable_gwh', x="Date", time='Year')
#average_lineplot_no_group_sol(df=data_df, y='Solar_gwh', x="Date", time='Year')
#average_lineplot_no_group_eng(df=data_df, y= 'Total_energy_generation_gwh', x="Date", time='Year')

# %%
#average_lineplot_no_group_ren(df=data_df, y='Total_other_renewable_gwh', x="Date", time='Month')
#average_lineplot_no_group_sol(df=data_df, y='Solar_gwh', x="Date", time='Month')
#average_lineplot_no_group_eng(df=data_df, y= 'Total_energy_generation_gwh', x="Date", time='Month')

# %%
#average_lineplot_no_group_sol(df=data_df, y='Solar_gwh', x="Date", time='Month')
#average_lineplot_no_group_Wind_onshore(df=data_df, y='Wind_onshore_gwh', x="Date", time='Month')
#average_lineplot_no_group_Wind_offshore(df=data_df, y= 'Wind_offshore_gwh', x="Date", time='Month')

# %%
columns_to_keep= ['Date', 'Solar_gwh', 'Wind_onshore_gwh', 'Wind_offshore_gwh', 'Total_energy_generation_gwh'] #'Total_other_renewable_gwh'
target = 'Total_energy_generation_gwh'
data_mlvt = data_df[columns_to_keep].copy()
data_mlvt.head()
# Out:
#         Date  Solar_gwh  Wind_onshore_gwh  Wind_offshore_gwh  \
# 0 2015-01-01        0.0           8.84975            0.52100
# 1 2015-01-01        0.0           9.04650            0.52075
# 2 2015-01-01        0.0           9.19600            0.51900
# 3 2015-01-01        0.0           9.14675            0.52250
# 4 2015-01-01        0.0           9.20400            0.52425
#
#    Total_energy_generation_gwh
# 0                     51.45925
# 1                     49.98825
# 2                     49.26525
# 3                     48.53800
# 4                     48.63000

# %%
def average_lineplots(df, y_values, x='Date', time='Year'):
    fig, axes = plt.subplots(len(y_values), 1, figsize=(10, 5 * len(y_values)))

    for idx, y in enumerate(y_values):
        grouped_df = df \
            .groupby([x, time], as_index=False) \
            .agg({y: np.sum}) \
            .set_index(x)

        ax = axes[idx]
        sns.lineplot(x=time, y=y, data=grouped_df, ax=ax, color='#33658A')
        y_label_00 = y.replace('_gwh', ' (GWh)')
        y_label_target0 = y_label_00.replace('_', ' ')
        ax.set(title='', ylabel=y_label_target0)
        ax.tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.show()
#average_lineplots(df=data_df, y_values=['Total_energy_generation_gwh', 'Total_other_renewable_gwh', 'Solar_gwh', 'Wind_onshore_gwh', 'Wind_offshore_gwh'], x="Date", time='Month')

# %%
def average_lineplot_no_group(df, y_values, x='Date', time='Year'):
    fig, ax = plt.subplots(figsize=(10, 6))

    for y in y_values:
        grouped_df = df \
            .groupby([x, time], as_index=False) \
            .agg({y: np.sum}) \
            .set_index(x)

        y_label_00 = y.replace('_gwh', ' (GWh)')
        y_label_target0 = y_label_00.replace('_', ' ')

        sns.lineplot(x=time, y=y, data=grouped_df, ax=ax, label=y_label_target0, marker='o')

    ax.set(title='', ylabel='Energy generation in (GWh)')
    ax.tick_params(axis='x', rotation=45)
    ax.legend()
    plt.tight_layout()

    # Remove '(GWh)' from the legend labels
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles=handles, labels=[label.replace(' (GWh)', '') for label in labels])

    plt.show()

average_lineplot_no_group(df=data_df, y_values=['Total_other_renewable_gwh', 'Solar_gwh', 'Wind_onshore_gwh', 'Wind_offshore_gwh'], x="Date", time='Month')   
#average_lineplot_no_group(df=data_df, y_values=['Total_energy_generation_gwh', 'Total_other_renewable_gwh', 'Solar_gwh', 'Wind_onshore_gwh', 'Wind_offshore_gwh'], x="Date", time='Month')
#average_lineplot_no_group(df=data_df, y_values=['Wind_onshore_gwh', 'Wind_offshore_gwh'], x="Date", time='Month')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 26
#      22     ax.legend(handles=handles, labels=[label.replace(' (GWh)', '') for label in labels])
#      24     plt.show()
# ---> 26 average_lineplot_no_group(df=data_df, y_values=['Total_other_renewable_gwh', 'Solar_gwh', 'Wind_onshore_gwh', 'Wind_offshore_gwh'], x="Date", time='Month')
#      27 #average_lineplot_no_group(df=data_df, y_values=['Total_energy_generation_gwh', 'Total_other_renewable_gwh', 'Solar_gwh', 'Wind_onshore_gwh', 'Wind_offshore_gwh'], x="Date", time='Month')
#      28 #average_lineplot_no_group(df=data_df, y_values=['Wind_onshore_gwh', 'Wind_offshore_gwh'], x="Date", time='Month')
#
# NameError: name 'data_df' is not defined

# %% [markdown]
# #### Multivariate LSTM

# %% [markdown]
# #### Working code

# %%
columns_to_keep= ['Date', 'Solar_gwh', 'Wind_onshore_gwh', 'Wind_offshore_gwh', 'Total_energy_generation_gwh'] #'Total_other_renewable_gwh'
target = 'Total_energy_generation_gwh'
features= ['Solar_gwh', 'Wind_onshore_gwh', 'Wind_offshore_gwh', 'Total_energy_generation_gwh']
data_mlvt = data_df[columns_to_keep].copy()
data_mlvt.head()
# Out:
#         Date  Solar_gwh  Wind_onshore_gwh  Wind_offshore_gwh  \
# 0 2015-01-01        0.0           8.84975            0.52100
# 1 2015-01-01        0.0           9.04650            0.52075
# 2 2015-01-01        0.0           9.19600            0.51900
# 3 2015-01-01        0.0           9.14675            0.52250
# 4 2015-01-01        0.0           9.20400            0.52425
#
#    Total_energy_generation_gwh
# 0                     51.45925
# 1                     49.98825
# 2                     49.26525
# 3                     48.53800
# 4                     48.63000
